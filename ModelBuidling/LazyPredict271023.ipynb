# %% [markdown]
# # The aim of this script to use lazy predict (https://github.com/shankarpandala/lazypredict) to build up a range of models quickly and evaluate their performance

# %% [markdown]
# The package version used in this script
#
# (note, changing the versions might lead to some errors)

# %%
conda list
# Out:
# # packages in environment at /Users/wintermute/opt/anaconda3/envs/modelbuilding:
# #
# # Name                    Version                   Build  Channel
# _py-xgboost-mutex         2.0                       cpu_0    conda-forge
# anyio                     3.6.2              pyhd8ed1ab_0    conda-forge
# appnope                   0.1.3              pyhd8ed1ab_0    conda-forge
# archspec                  0.2.1              pyhd8ed1ab_1    conda-forge
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0           py38hb991d35_3    conda-forge
# asttokens                 2.2.1              pyhd8ed1ab_0    conda-forge
# atk-1.0                   2.38.0               hcb7b3dd_1    conda-forge
# attrs                     22.2.0             pyh71513ae_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                pyhd8ed1ab_3    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# beautifulsoup4            4.11.2             pyha770c72_0    conda-forge
# bleach                    6.0.0              pyhd8ed1ab_0    conda-forge
# boltons                   23.0.0             pyhd8ed1ab_0    conda-forge
# brotli                    1.1.0                hb547adb_1    conda-forge
# brotli-bin                1.1.0                hb547adb_1    conda-forge
# brotli-python             1.1.0            py38he333c0f_1    conda-forge
# bzip2                     1.0.8                h3422bc3_4    conda-forge
# c-ares                    1.20.1               h93a5062_1    conda-forge
# ca-certificates           2023.7.22            hf0a4a13_0    conda-forge
# cairo                     1.18.0               hd1e100b_0    conda-forge
# certifi                   2023.7.22          pyhd8ed1ab_0    conda-forge
# cffi                      1.16.0           py38h73f40f7_0    conda-forge
# charset-normalizer        3.3.1              pyhd8ed1ab_0    conda-forge
# click                     8.1.3                    pypi_0    pypi
# cloudpickle               3.0.0              pyhd8ed1ab_0    conda-forge
# colorama                  0.4.6              pyhd8ed1ab_0    conda-forge
# comm                      0.1.2              pyhd8ed1ab_0    conda-forge
# conda                     23.9.0           py38h10201cd_2    conda-forge
# conda-package-handling    2.2.0              pyh38be061_0    conda-forge
# conda-package-streaming   0.9.0              pyhd8ed1ab_0    conda-forge
# contourpy                 1.1.1            py38h9afee92_1    conda-forge
# cryptography              41.0.5           py38h4e52f8d_0    conda-forge
# cycler                    0.12.1             pyhd8ed1ab_0    conda-forge
# debugpy                   1.6.6            py38h2b1e499_0    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# dowhy                     0.8                pyhd8ed1ab_0    conda-forge
# econml                    0.12.0           py38h3777fb4_1    conda-forge
# entrypoints               0.4                pyhd8ed1ab_0    conda-forge
# et_xmlfile                1.1.0              pyhd8ed1ab_0    conda-forge
# executing                 1.2.0              pyhd8ed1ab_0    conda-forge
# expat                     2.5.0                hb7217d7_1    conda-forge
# flit-core                 3.8.0              pyhd8ed1ab_0    conda-forge
# fmt                       10.1.1               h1995070_0    conda-forge
# font-ttf-dejavu-sans-mono 2.37                 hab24e00_0    conda-forge
# font-ttf-inconsolata      3.000                h77eed37_0    conda-forge
# font-ttf-source-code-pro  2.038                h77eed37_0    conda-forge
# font-ttf-ubuntu           0.83                 hab24e00_0    conda-forge
# fontconfig                2.14.2               h82840c6_0    conda-forge
# fonts-conda-ecosystem     1                             0    conda-forge
# fonts-conda-forge         1                             0    conda-forge
# fonttools                 4.43.1           py38h336bac9_0    conda-forge
# freetype                  2.12.1               hadb7bae_2    conda-forge
# fribidi                   1.0.10               h27ca646_0    conda-forge
# gdk-pixbuf                2.42.10              he313114_3    conda-forge
# gettext                   0.21.1               h0186832_0    conda-forge
# giflib                    5.2.1                h1a8c8d9_3    conda-forge
# gmp                       6.3.0                h965bd2d_0    conda-forge
# gmpy2                     2.1.2            py38h904d018_1    conda-forge
# graphite2                 1.3.13            h9f76cd9_1001    conda-forge
# graphviz                  8.1.0                h10878c0_0    conda-forge
# gtk2                      2.24.33              h57013de_2    conda-forge
# gts                       0.7.6                he42f4ea_4    conda-forge
# harfbuzz                  8.3.0                h8f0ba13_0    conda-forge
# icu                       73.2                 hc8870d7_0    conda-forge
# idna                      3.4                pyhd8ed1ab_0    conda-forge
# importlib-metadata        6.0.0              pyha770c72_0    conda-forge
# importlib-resources       5.12.0             pyhd8ed1ab_0    conda-forge
# importlib_metadata        6.0.0                hd8ed1ab_0    conda-forge
# importlib_resources       5.12.0             pyhd8ed1ab_0    conda-forge
# ipykernel                 6.21.2             pyh736e0ef_0    conda-forge
# ipython                   8.10.0             pyhd1c38e8_0    conda-forge
# ipython_genutils          0.2.0                      py_1    conda-forge
# ipywidgets                8.0.4              pyhd8ed1ab_0    conda-forge
# jedi                      0.18.2             pyhd8ed1ab_0    conda-forge
# jinja2                    3.1.2              pyhd8ed1ab_1    conda-forge
# joblib                    1.2.0                    pypi_0    pypi
# jsonpatch                 1.33               pyhd8ed1ab_0    conda-forge
# jsonpointer               2.4              py38h10201cd_3    conda-forge
# jsonschema                4.17.3             pyhd8ed1ab_0    conda-forge
# jupyter                   1.0.0            py38h10201cd_8    conda-forge
# jupyter_client            8.0.3              pyhd8ed1ab_0    conda-forge
# jupyter_console           6.6.1              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.2.0            py38h10201cd_0    conda-forge
# jupyter_events            0.6.3              pyhd8ed1ab_0    conda-forge
# jupyter_server            2.3.0              pyhd8ed1ab_0    conda-forge
# jupyter_server_terminals  0.4.4              pyhd8ed1ab_1    conda-forge
# jupyterlab_pygments       0.2.2              pyhd8ed1ab_0    conda-forge
# jupyterlab_widgets        3.0.5              pyhd8ed1ab_0    conda-forge
# kiwisolver                1.4.5            py38h9afee92_1    conda-forge
# krb5                      1.21.2               h92f50d5_0    conda-forge
# lazypredict               0.2.12                   pypi_0    pypi
# lcms2                     2.15                 h40e5a24_2    conda-forge
# lerc                      4.0.0                h9a09cb3_0    conda-forge
# libarchive                3.7.2                h82b9b87_0    conda-forge
# libblas                   3.9.0           19_osxarm64_openblas    conda-forge
# libbrotlicommon           1.1.0                hb547adb_1    conda-forge
# libbrotlidec              1.1.0                hb547adb_1    conda-forge
# libbrotlienc              1.1.0                hb547adb_1    conda-forge
# libcblas                  3.9.0           19_osxarm64_openblas    conda-forge
# libcurl                   8.4.0                h2d989ff_0    conda-forge
# libcxx                    16.0.6               h4653b0c_0    conda-forge
# libdeflate                1.19                 hb547adb_0    conda-forge
# libedit                   3.1.20191231         hc8eb9b7_2    conda-forge
# libev                     4.33                 h642e427_1    conda-forge
# libexpat                  2.5.0                hb7217d7_1    conda-forge
# libffi                    3.4.2                h3422bc3_5    conda-forge
# libgd                     2.3.3                h574d10c_8    conda-forge
# libgfortran               5.0.0           13_2_0_hd922786_1    conda-forge
# libgfortran5              13.2.0               hf226fd6_1    conda-forge
# libglib                   2.78.1               hd9b11f9_0    conda-forge
# libiconv                  1.17                 he4db4b2_0    conda-forge
# libjpeg-turbo             2.1.5.1              hb547adb_1    conda-forge
# liblapack                 3.9.0           19_osxarm64_openblas    conda-forge
# libllvm14                 14.0.6               hd1a9a77_4    conda-forge
# libmamba                  1.5.2                h0a6dc31_0    conda-forge
# libmambapy                1.5.2            py38h7b814e7_0    conda-forge
# libnghttp2                1.52.0               hae82a92_0    conda-forge
# libopenblas               0.3.24          openmp_hd76b1f2_0    conda-forge
# libpng                    1.6.39               h76d750c_0    conda-forge
# librsvg                   2.56.3               h0db3404_0    conda-forge
# libsodium                 1.0.18               h27ca646_1    conda-forge
# libsolv                   0.7.25               ha614eb4_0    conda-forge
# libsqlite                 3.40.0               h76d750c_0    conda-forge
# libssh2                   1.11.0               h7a5bd25_0    conda-forge
# libtiff                   4.6.0                h77c4dce_1    conda-forge
# libtool                   2.4.7                hb7217d7_0    conda-forge
# libwebp                   1.3.2                h9393c0e_0    conda-forge
# libwebp-base              1.3.2                hb547adb_0    conda-forge
# libxcb                    1.15                 hf346824_0    conda-forge
# libxgboost                1.7.6            cpu_hb5d148d_5    conda-forge
# libxml2                   2.11.5               h25269f3_1    conda-forge
# libzlib                   1.2.13               h03a7124_4    conda-forge
# lightgbm                  3.3.5                    pypi_0    pypi
# littleutils               0.2.2                    pypi_0    pypi
# llvm-openmp               17.0.3               hcd81f8e_0    conda-forge
# llvmlite                  0.40.1           py38h761d82c_0    conda-forge
# lz4-c                     1.9.4                hb7217d7_0    conda-forge
# lzo                       2.10              h642e427_1000    conda-forge
# mamba                     1.5.2            py38hb2d7053_0    conda-forge
# markupsafe                2.1.2            py38hb991d35_0    conda-forge
# matplotlib                3.7.3            py38h150bfb4_0    conda-forge
# matplotlib-base           3.7.3            py38hef9d0d7_0    conda-forge
# matplotlib-inline         0.1.6              pyhd8ed1ab_0    conda-forge
# mistune                   2.0.5              pyhd8ed1ab_0    conda-forge
# mpc                       1.3.1                h91ba8db_0    conda-forge
# mpfr                      4.2.1                h9546428_0    conda-forge
# mpmath                    1.3.0              pyhd8ed1ab_0    conda-forge
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# nbclassic                 0.5.2              pyhd8ed1ab_0    conda-forge
# nbclient                  0.7.2              pyhd8ed1ab_0    conda-forge
# nbconvert                 7.2.9              pyhd8ed1ab_0    conda-forge
# nbconvert-core            7.2.9              pyhd8ed1ab_0    conda-forge
# nbconvert-pandoc          7.2.9              pyhd8ed1ab_0    conda-forge
# nbformat                  5.7.3              pyhd8ed1ab_0    conda-forge
# ncurses                   6.3                  h07bb92c_1    conda-forge
# nest-asyncio              1.5.6              pyhd8ed1ab_0    conda-forge
# networkx                  3.1                pyhd8ed1ab_0    conda-forge
# notebook                  6.5.2              pyha770c72_1    conda-forge
# notebook-shim             0.2.2              pyhd8ed1ab_0    conda-forge
# numba                     0.57.1           py38h11be589_0    conda-forge
# numpy                     1.24.2                   pypi_0    pypi
# openjpeg                  2.5.0                h4c1507b_3    conda-forge
# openpyxl                  3.1.2            py38hb192615_1    conda-forge
# openssl                   3.1.4                h0d3ecfb_0    conda-forge
# outdated                  0.2.2                    pypi_0    pypi
# packaging                 23.0               pyhd8ed1ab_0    conda-forge
# pandas                    1.5.3                    pypi_0    pypi
# pandas-flavor             0.6.0                    pypi_0    pypi
# pandoc                    2.19.2               hce30654_1    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# pango                     1.50.14              hcf40dda_2    conda-forge
# parso                     0.8.3              pyhd8ed1ab_0    conda-forge
# patsy                     0.5.3              pyhd8ed1ab_0    conda-forge
# pcre2                     10.40                hb34f9b4_0    conda-forge
# pexpect                   4.8.0              pyh1a96a4e_2    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    10.0.1           py38hf19b724_1    conda-forge
# pingouin                  0.5.3                    pypi_0    pypi
# pip                       23.0.1             pyhd8ed1ab_0    conda-forge
# pixman                    0.42.2               h13dd4ca_0    conda-forge
# pkgutil-resolve-name      1.3.10             pyhd8ed1ab_0    conda-forge
# platformdirs              3.0.0              pyhd8ed1ab_0    conda-forge
# pluggy                    1.3.0              pyhd8ed1ab_0    conda-forge
# pooch                     1.8.0              pyhd8ed1ab_0    conda-forge
# prometheus_client         0.16.0             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.36             pyha770c72_0    conda-forge
# prompt_toolkit            3.0.36               hd8ed1ab_0    conda-forge
# psutil                    5.9.4            py38hb991d35_0    conda-forge
# pthread-stubs             0.4               h27ca646_1001    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.2              pyhd8ed1ab_0    conda-forge
# py-xgboost                1.7.6           cpu_py38hb442362_5    conda-forge
# pybind11-abi              4                    hd8ed1ab_3    conda-forge
# pycosat                   0.6.6            py38hb192615_0    conda-forge
# pycparser                 2.21               pyhd8ed1ab_0    conda-forge
# pydot                     1.4.2            py38h10201cd_4    conda-forge
# pygments                  2.14.0             pyhd8ed1ab_0    conda-forge
# pygraphviz                1.11             py38h1f93a86_1    conda-forge
# pyopenssl                 23.2.0             pyhd8ed1ab_1    conda-forge
# pyparsing                 3.1.1              pyhd8ed1ab_0    conda-forge
# pyrsistent                0.19.3           py38hb991d35_0    conda-forge
# pysocks                   1.7.1              pyha2e5f31_6    conda-forge
# python                    3.8.16          h3ba56d0_1_cpython    conda-forge
# python-dateutil           2.8.2              pyhd8ed1ab_0    conda-forge
# python-fastjsonschema     2.16.2             pyhd8ed1ab_0    conda-forge
# python-graphviz           0.20.1             pyh22cad53_0    conda-forge
# python-json-logger        2.0.7              pyhd8ed1ab_0    conda-forge
# python-tzdata             2023.3             pyhd8ed1ab_0    conda-forge
# python_abi                3.8                      3_cp38    conda-forge
# pytz                      2022.7.1                 pypi_0    pypi
# pyyaml                    6.0              py38hb991d35_5    conda-forge
# pyzmq                     25.0.0           py38hb72be9f_0    conda-forge
# readline                  8.1.2                h46ed386_0    conda-forge
# reproc                    14.2.4.post0         h93a5062_1    conda-forge
# reproc-cpp                14.2.4.post0         h965bd2d_1    conda-forge
# requests                  2.31.0             pyhd8ed1ab_0    conda-forge
# rfc3339-validator         0.1.4              pyhd8ed1ab_0    conda-forge
# rfc3986-validator         0.1.1              pyh9f0ad1d_0    conda-forge
# ruamel.yaml               0.17.40          py38h336bac9_0    conda-forge
# ruamel.yaml.clib          0.2.7            py38hb192615_2    conda-forge
# scikit-learn              1.2.1                    pypi_0    pypi
# scipy                     1.10.1           py38h038e806_3    conda-forge
# seaborn                   0.13.0               hd8ed1ab_0    conda-forge
# seaborn-base              0.13.0             pyhd8ed1ab_0    conda-forge
# send2trash                1.8.0              pyhd8ed1ab_0    conda-forge
# setuptools                67.4.0             pyhd8ed1ab_0    conda-forge
# shap                      0.39.0           py38h3777fb4_1    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# slicer                    0.0.7              pyhd8ed1ab_0    conda-forge
# sniffio                   1.3.0              pyhd8ed1ab_0    conda-forge
# soupsieve                 2.3.2.post1        pyhd8ed1ab_0    conda-forge
# sparse                    0.14.0             pyhd8ed1ab_0    conda-forge
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# statsmodels               0.14.0           py38hd97cf01_2    conda-forge
# sympy                     1.12            pypyh9d50eac_103    conda-forge
# tabulate                  0.9.0                    pypi_0    pypi
# terminado                 0.17.1             pyhd1c38e8_0    conda-forge
# threadpoolctl             3.1.0                    pypi_0    pypi
# tinycss2                  1.2.1              pyhd8ed1ab_0    conda-forge
# tk                        8.6.12               he1e0b03_0    conda-forge
# tornado                   6.2              py38hb991d35_1    conda-forge
# tqdm                      4.64.1                   pypi_0    pypi
# traitlets                 5.9.0              pyhd8ed1ab_0    conda-forge
# typing-extensions         4.4.0                hd8ed1ab_0    conda-forge
# typing_extensions         4.4.0              pyha770c72_0    conda-forge
# unicodedata2              15.1.0           py38hb192615_0    conda-forge
# urllib3                   2.0.7              pyhd8ed1ab_0    conda-forge
# wcwidth                   0.2.6              pyhd8ed1ab_0    conda-forge
# webencodings              0.5.1                      py_1    conda-forge
# websocket-client          1.5.1              pyhd8ed1ab_0    conda-forge
# wheel                     0.38.4             pyhd8ed1ab_0    conda-forge
# widgetsnbextension        4.0.5              pyhd8ed1ab_0    conda-forge
# xarray                    2023.1.0                 pypi_0    pypi
# xgboost                   1.7.4                    pypi_0    pypi
# xorg-libxau               1.0.11               hb547adb_0    conda-forge
# xorg-libxdmcp             1.1.3                h27ca646_0    conda-forge
# xz                        5.2.6                h57fd34a_0    conda-forge
# yaml                      0.2.5                h3422bc3_2    conda-forge
# yaml-cpp                  0.8.0                h13dd4ca_0    conda-forge
# zeromq                    4.3.4                hbdafb3b_1    conda-forge
# zipp                      3.14.0             pyhd8ed1ab_0    conda-forge
# zlib                      1.2.13               h03a7124_4    conda-forge
# zstandard                 0.21.0           py38he9c5048_1    conda-forge
# zstd                      1.5.5                h4f39d0f_0    conda-forge
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict 
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import lazypredict
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## RMSF 442 residues only as X vs lnv as Y

# %% [markdown]
# ### lnv as only Y variable

# %%
# read the excel data of the rmsf of 442 residues and their aggregation rates

rmsf_agg = pd.read_excel("rmsf_442residues_agg.xlsx",index_col=0)

# Select the columns 0 to 441 as predictor variables (X)

X = rmsf_agg.iloc[:, 0:442]  

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = rmsf_agg['ln(v)']  

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  21%|█████████▍                                  | 9/42 [00:02<00:10,  3.16it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  62%|██████████████████████████▌                | 26/42 [00:06<00:02,  5.36it/s]
# LassoLarsIC model failed to execute
# You are using LassoLarsIC in the case where the number of samples is smaller than the number of features. In this setting, getting a good estimate for the variance of the noise is not possible. Provide an estimate of the noise variance in the constructor.
#  76%|████████████████████████████████▊          | 32/42 [00:06<00:01,  9.80it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# RANSACRegressor model failed to execute
# `min_samples` may not be larger than number of samples: n_samples = 39.
# 100%|███████████████████████████████████████████| 42/42 [00:06<00:00,  6.15it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.057444
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                          Adjusted R-Squared  \
# Model
# Lars                          83484922623407747170828288.00
# QuantileRegressor                                      1.04
# OrthogonalMatchingPursuit                              1.04
# DecisionTreeRegressor                                  1.03
# ExtraTreeRegressor                                     1.03
# XGBRegressor                                           1.03
# GaussianProcessRegressor                               1.02
# DummyRegressor                                         1.02
# HistGradientBoostingRegressor                          1.02
# LGBMRegressor                                          1.02
# TransformedTargetRegressor                             1.01
# LinearRegression                                       1.01
# LinearSVR                                              1.01
# HuberRegressor                                         1.01
# KernelRidge                                            1.01
# LarsCV                                                 1.01
# SGDRegressor                                           1.01
# Ridge                                                  1.01
# PassiveAggressiveRegressor                             1.01
# OrthogonalMatchingPursuitCV                            1.01
# BaggingRegressor                                       1.01
# RidgeCV                                                1.01
# MLPRegressor                                           1.01
# TweedieRegressor                                       1.01
# BayesianRidge                                          1.01
# ExtraTreesRegressor                                    1.01
# RandomForestRegressor                                  1.01
# KNeighborsRegressor                                    1.01
# ElasticNetCV                                           1.01
# LassoCV                                                1.01
# LassoLarsCV                                            1.01
# GradientBoostingRegressor                              1.01
# ElasticNet                                             1.01
# SVR                                                    1.00
# LassoLars                                              1.00
# Lasso                                                  1.00
# NuSVR                                                  1.00
# AdaBoostRegressor                                      1.00
#
#                                                      R-Squared  \
# Model
# Lars                          -4016552388437284298055221248.00
# QuantileRegressor                                        -0.74
# OrthogonalMatchingPursuit                                -0.70
# DecisionTreeRegressor                                    -0.44
# ExtraTreeRegressor                                       -0.38
# XGBRegressor                                             -0.22
# GaussianProcessRegressor                                 -0.03
# DummyRegressor                                           -0.02
# HistGradientBoostingRegressor                            -0.02
# LGBMRegressor                                            -0.02
# TransformedTargetRegressor                                0.57
# LinearRegression                                          0.57
# LinearSVR                                                 0.57
# HuberRegressor                                            0.57
# KernelRidge                                               0.57
# LarsCV                                                    0.57
# SGDRegressor                                              0.58
# Ridge                                                     0.58
# PassiveAggressiveRegressor                                0.59
# OrthogonalMatchingPursuitCV                               0.59
# BaggingRegressor                                          0.60
# RidgeCV                                                   0.61
# MLPRegressor                                              0.62
# TweedieRegressor                                          0.63
# BayesianRidge                                             0.65
# ExtraTreesRegressor                                       0.69
# RandomForestRegressor                                     0.71
# KNeighborsRegressor                                       0.73
# ElasticNetCV                                              0.75
# LassoCV                                                   0.75
# LassoLarsCV                                               0.75
# GradientBoostingRegressor                                 0.76
# ElasticNet                                                0.76
# SVR                                                       0.76
# LassoLars                                                 0.78
# Lasso                                                     0.78
# NuSVR                                                     0.81
# AdaBoostRegressor                                         0.87
#
#                                             RMSE  Time Taken
# Model
# Lars                          245091531324330.03        0.13
# QuantileRegressor                           5.10        0.04
# OrthogonalMatchingPursuit                   5.05        0.01
# DecisionTreeRegressor                       4.64        0.02
# ExtraTreeRegressor                          4.54        0.01
# XGBRegressor                                4.27        0.09
# GaussianProcessRegressor                    3.92        0.01
# DummyRegressor                              3.91        0.01
# HistGradientBoostingRegressor               3.91        0.10
# LGBMRegressor                               3.91        0.02
# TransformedTargetRegressor                  2.54        0.01
# LinearRegression                            2.54        0.01
# LinearSVR                                   2.54        0.02
# HuberRegressor                              2.54        0.04
# KernelRidge                                 2.54        0.01
# LarsCV                                      2.53        0.63
# SGDRegressor                                2.52        0.02
# Ridge                                       2.52        0.01
# PassiveAggressiveRegressor                  2.48        0.01
# OrthogonalMatchingPursuitCV                 2.46        0.02
# BaggingRegressor                            2.44        0.06
# RidgeCV                                     2.41        0.01
# MLPRegressor                                2.40        0.15
# TweedieRegressor                            2.34        0.02
# BayesianRidge                               2.28        0.02
# ExtraTreesRegressor                         2.14        0.30
# RandomForestRegressor                       2.10        0.47
# KNeighborsRegressor                         2.01        0.06
# ElasticNetCV                                1.95        2.05
# LassoCV                                     1.93        1.65
# LassoLarsCV                                 1.92        0.07
# GradientBoostingRegressor                   1.91        0.47
# ElasticNet                                  1.90        0.01
# SVR                                         1.89        0.01
# LassoLars                                   1.83        0.01
# Lasso                                       1.83        0.01
# NuSVR                                       1.66        0.01
# AdaBoostRegressor                           1.39        0.16

# %% [markdown]
# ### lnv and Tm as two Y variables

# %%
# read the excel data of the rmsf of 442 residues and their aggregation rates

rmsf_agg = pd.read_excel("rmsf_442residues_agg.xlsx",index_col=0)

# Select the columns 0 to 441 as predictor variables (X)

X = rmsf_agg.iloc[:, 0:442]  

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' and 'Tm' are the target Y variables

Y = rmsf_agg[['Tm', 'ln(v)']] 

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  10%|████▏                                       | 4/42 [00:00<00:00, 39.89it/s]
# AdaBoostRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# BayesianRidge model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# ElasticNetCV model failed to execute
# For multi-task outputs, use MultiTaskElasticNetCV
#  21%|█████████▍                                  | 9/42 [00:00<00:01, 17.31it/s]
# GammaRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# GradientBoostingRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# HistGradientBoostingRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# HuberRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
#  40%|█████████████████▍                         | 17/42 [00:00<00:01, 20.09it/s]
# LarsCV model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# LassoCV model failed to execute
# For multi-task outputs, use MultiTaskLassoCV
# LassoLarsCV model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# LassoLarsIC model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# LinearSVR model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
#  62%|██████████████████████████▌                | 26/42 [00:01<00:00, 22.30it/s]
# NuSVR model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# OrthogonalMatchingPursuitCV model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# PassiveAggressiveRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# PoissonRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# QuantileRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# RANSACRegressor model failed to execute
# `min_samples` may not be larger than number of samples: n_samples = 39.
#  93%|███████████████████████████████████████▉   | 39/42 [00:01<00:00, 20.58it/s]
# SGDRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# SVR model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# TweedieRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# 100%|███████████████████████████████████████████| 42/42 [00:02<00:00, 19.37it/s]
# LGBMRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
#                                                     Adjusted R-Squared  \
# Model
# Lars                       4422323249223712893251464209227269013504.00
# GaussianProcessRegressor                                          4.57
# KernelRidge                                                       4.52
# MLPRegressor                                                      1.34
# ExtraTreeRegressor                                                1.11
# OrthogonalMatchingPursuit                                         1.08
# DecisionTreeRegressor                                             1.08
# LinearRegression                                                  1.03
# TransformedTargetRegressor                                        1.03
# Ridge                                                             1.03
# RidgeCV                                                           1.03
# BaggingRegressor                                                  1.03
# XGBRegressor                                                      1.02
# DummyRegressor                                                    1.02
# RandomForestRegressor                                             1.02
# ExtraTreesRegressor                                               1.02
# Lasso                                                             1.02
# LassoLars                                                         1.02
# ElasticNet                                                        1.02
# KNeighborsRegressor                                               1.01
#
#                                                                 R-Squared  \
# Model
# Lars                       -212762885212651976775193873122746513227776.00
# GaussianProcessRegressor                                          -170.83
# KernelRidge                                                       -168.46
# MLPRegressor                                                       -15.18
# ExtraTreeRegressor                                                  -4.22
# OrthogonalMatchingPursuit                                           -2.91
# DecisionTreeRegressor                                               -2.86
# LinearRegression                                                    -0.65
# TransformedTargetRegressor                                          -0.65
# Ridge                                                               -0.63
# RidgeCV                                                             -0.47
# BaggingRegressor                                                    -0.29
# XGBRegressor                                                        -0.15
# DummyRegressor                                                      -0.09
# RandomForestRegressor                                               -0.01
# ExtraTreesRegressor                                                  0.07
# Lasso                                                                0.09
# LassoLars                                                            0.09
# ElasticNet                                                           0.10
# KNeighborsRegressor                                                  0.28
#
#                                                 RMSE  Time Taken
# Model
# Lars                       1783813814271569297408.00        0.29
# GaussianProcessRegressor                       53.61        0.01
# KernelRidge                                    53.24        0.01
# MLPRegressor                                   16.44        0.28
# ExtraTreeRegressor                              9.26        0.01
# OrthogonalMatchingPursuit                       7.99        0.02
# DecisionTreeRegressor                           7.95        0.02
# LinearRegression                                5.22        0.01
# TransformedTargetRegressor                      5.22        0.03
# Ridge                                           5.18        0.03
# RidgeCV                                         4.92        0.03
# BaggingRegressor                                4.60        0.07
# XGBRegressor                                    4.27        0.22
# DummyRegressor                                  4.17        0.01
# RandomForestRegressor                           4.07        0.56
# ExtraTreesRegressor                             3.91        0.33
# Lasso                                           3.87        0.01
# LassoLars                                       3.87        0.01
# ElasticNet                                      3.85        0.02
# KNeighborsRegressor                             3.43        0.01

# %% [markdown]
# # SASA of 7 APRs, RMSF vs lnv

# %%
import pandas as pd

# Read SASA of 7 APR data from the excel 
sasa_apr = pd.read_excel("SASA_7APRs_54conditions231023.xlsx",index_col=0)

# read the excel data of the rmsf of 442 residues and their aggregation rates

rmsf_agg = pd.read_excel("rmsf_442residues_agg.xlsx",index_col=0)

# add a column of the sum of SASA of all APRs
sasa_apr["sum_aprsasa"] = sasa_apr.sum(axis = 1)

rmsf_sasa_agg = pd.concat([sasa_apr,rmsf_agg],axis=1,join='inner')

# Save the dataframe into an excel file
# rmsf_sasa_agg.to_excel("rmsf_sasa_agg311023.xlsx")

# %%
rmsf_sasa_agg
# Out:
#               r_31-36  r_47-51  r_114-118  r_129-139  r_261-265  r_325-329  \
# 3_5_277_0        0.37     0.02       0.25       0.18      -0.11       0.07
# 8_338_0          0.71     0.57       0.32       0.15       0.58       0.54
# 3_5_338_100      0.61     0.44       0.87       1.05       0.09       0.14
# 3_5_338_200      1.13     0.58       0.48       0.85       0.65       0.56
# 5_5_296_250      0.28     0.09       0.08       0.49       0.27       0.18
# 9_338_200        1.05     0.47       0.25       0.76       0.28       0.41
# 318K_7_250M      0.73     0.45       0.29       0.21       0.31       0.27
# 3_5_277_50       0.37     0.24       0.10       0.13       0.10      -0.05
# 296K_7_50M       0.15     0.08       0.11      -0.21       0.25       0.08
# 4_5_296_250      0.66     0.29       0.44       0.50       0.34       0.39
# 318_4_5_150M     0.21    -0.06      -0.10       0.03      -0.10       0.01
# 7_296_250        0.62     0.38      -0.05       0.04       0.22      -0.04
# 8_338_500        0.89     0.53       0.48       0.36       0.19       0.26
# 7_338_0          1.17     0.61       0.61       0.96       0.63       0.44
# 9_338_100        0.81     0.67       0.74       1.23       0.81       0.68
# 277_3_5_150M     0.15     0.17       0.11       0.11       0.08      -0.04
# 3_5_338_250      0.79     0.55       0.30       0.81       0.48       0.47
# 9_338_500        1.22     0.57       0.68       0.95       0.60       0.29
# 3_5_338_150      0.44     0.10       0.24       0.48       0.23       0.13
# 5_5_296_100      0.51    -0.00       0.31       0.16      -0.15       0.23
# 4_5_338_0        0.80     0.39       0.17       0.37       0.53       0.47
# 4_5_338_50   0.76 0.84 0.96 75.00   4.90
# 277K_7_150M  0.76 0.93 1.14 78.63  -5.32
# 296_3_5_250M 0.77 0.87 1.04 59.52  -3.81
# 4_5_338_100  0.48 0.58 0.68 73.96   5.60
# 7_296_150    0.75 0.91 1.09 78.63  -4.02
# 8_338_200    0.60 0.67 0.78 77.94   2.18
# 4_5_338_150  0.63 0.75 0.90 73.31   6.54
# 277_4_5_250M 0.64 0.80 0.96 73.07  -3.59
#
# [49 rows x 452 columns]

# %% [markdown]
# ### Using 7 APRs plus their sum, RMSF residues as features to fit into models with one Y variable lnv

# %%
# Select the columns 0 to 441 as predictor variables (X)

X = rmsf_sasa_agg.iloc[:, 0:449]  

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = rmsf_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  21%|█████████▍                                  | 9/42 [00:09<00:37,  1.14s/it]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  62%|██████████████████████████▌                | 26/42 [00:16<00:07,  2.26it/s]
# LassoLarsIC model failed to execute
# You are using LassoLarsIC in the case where the number of samples is smaller than the number of features. In this setting, getting a good estimate for the variance of the noise is not possible. Provide an estimate of the noise variance in the constructor.
#  76%|████████████████████████████████▊          | 32/42 [00:16<00:02,  4.62it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# RANSACRegressor model failed to execute
# `min_samples` may not be larger than number of samples: n_samples = 39.
# 100%|███████████████████████████████████████████| 42/42 [00:17<00:00,  2.45it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.057444
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                           Adjusted R-Squared  \
# Model
# LarsCV                        272913971101401678440562688.00
# Lars                          272913971101401678440562688.00
# SGDRegressor                                            1.16
# OrthogonalMatchingPursuit                               1.10
# ExtraTreeRegressor                                      1.06
# LinearRegression                                        1.05
# TransformedTargetRegressor                              1.05
# HuberRegressor                                          1.05
# LinearSVR                                               1.05
# KernelRidge                                             1.05
# Ridge                                                   1.05
# PassiveAggressiveRegressor                              1.05
# RidgeCV                                                 1.04
# DecisionTreeRegressor                                   1.04
# QuantileRegressor                                       1.04
# KNeighborsRegressor                                     1.04
# TweedieRegressor                                        1.03
# BaggingRegressor                                        1.03
# MLPRegressor                                            1.03
# OrthogonalMatchingPursuitCV                             1.03
# AdaBoostRegressor                                       1.03
# SVR                                                     1.03
# XGBRegressor                                            1.02
# ElasticNet                                              1.02
# GradientBoostingRegressor                               1.02
# LassoLars                                               1.02
# Lasso                                                   1.02
# GaussianProcessRegressor                                1.02
# LassoLarsCV                                             1.02
# LassoCV                                                 1.02
# HistGradientBoostingRegressor                           1.02
# ElasticNetCV                                            1.02
# DummyRegressor                                          1.02
# LGBMRegressor                                           1.02
# NuSVR                                                   1.02
# RandomForestRegressor                                   1.02
# BayesianRidge                                           1.02
# ExtraTreesRegressor                                     1.02
#
#                                                       R-Squared  \
# Model
# LarsCV                        -13342460809401860690047664128.00
# Lars                          -13342460809401860690047664128.00
# SGDRegressor                                              -6.61
# OrthogonalMatchingPursuit                                 -3.75
# ExtraTreeRegressor                                        -2.07
# LinearRegression                                          -1.58
# TransformedTargetRegressor                                -1.58
# HuberRegressor                                            -1.58
# LinearSVR                                                 -1.58
# KernelRidge                                               -1.54
# Ridge                                                     -1.53
# PassiveAggressiveRegressor                                -1.52
# RidgeCV                                                   -1.18
# DecisionTreeRegressor                                     -0.91
# QuantileRegressor                                         -0.74
# KNeighborsRegressor                                       -0.72
# TweedieRegressor                                          -0.69
# BaggingRegressor                                          -0.48
# MLPRegressor                                              -0.44
# OrthogonalMatchingPursuitCV                               -0.27
# AdaBoostRegressor                                         -0.26
# SVR                                                       -0.26
# XGBRegressor                                              -0.20
# ElasticNet                                                -0.14
# GradientBoostingRegressor                                 -0.13
# LassoLars                                                 -0.03
# Lasso                                                     -0.03
# GaussianProcessRegressor                                  -0.03
# LassoLarsCV                                               -0.02
# LassoCV                                                   -0.02
# HistGradientBoostingRegressor                             -0.02
# ElasticNetCV                                              -0.02
# DummyRegressor                                            -0.02
# LGBMRegressor                                             -0.02
# NuSVR                                                     -0.01
# RandomForestRegressor                                      0.01
# BayesianRidge                                              0.02
# ExtraTreesRegressor                                        0.18
#
#                                             RMSE  Time Taken
# Model
# LarsCV                        446703705707085.06        0.75
# Lars                          446703705707085.06        0.13
# SGDRegressor                               10.67        0.01
# OrthogonalMatchingPursuit                   8.42        0.01
# ExtraTreeRegressor                          6.78        0.01
# LinearRegression                            6.22        0.01
# TransformedTargetRegressor                  6.22        0.01
# HuberRegressor                              6.22        0.04
# LinearSVR                                   6.21        0.02
# KernelRidge                                 6.17        0.01
# Ridge                                       6.15        0.01
# PassiveAggressiveRegressor                  6.14        0.02
# RidgeCV                                     5.70        0.01
# DecisionTreeRegressor                       5.34        0.02
# QuantileRegressor                           5.10        0.04
# KNeighborsRegressor                         5.07        0.08
# TweedieRegressor                            5.02        0.02
# BaggingRegressor                            4.71        0.07
# MLPRegressor                                4.64        0.15
# OrthogonalMatchingPursuitCV                 4.35        0.02
# AdaBoostRegressor                           4.35        0.18
# SVR                                         4.34        0.01
# XGBRegressor                                4.23        0.11
# ElasticNet                                  4.13        0.01
# GradientBoostingRegressor                   4.12        0.49
# LassoLars                                   3.92        0.01
# Lasso                                       3.92        0.01
# GaussianProcessRegressor                    3.92        0.01
# LassoLarsCV                                 3.91        0.06
# LassoCV                                     3.91        4.72
# HistGradientBoostingRegressor               3.91        0.12
# ElasticNetCV                                3.91        8.99
# DummyRegressor                              3.91        0.01
# LGBMRegressor                               3.91        0.03
# NuSVR                                       3.89        0.01
# RandomForestRegressor                       3.84        0.54
# BayesianRidge                               3.82        0.02
# ExtraTreesRegressor                         3.50        0.31

# %% [markdown]
# #### Using 7 APRs plus their sum, RMSF residues as features to fit into models with two Y variable lnv, Tm

# %%
# Select the columns 0 to 441 as predictor variables (X)

X = rmsf_sasa_agg.iloc[:, 0:449]  

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = rmsf_agg[['ln(v)','Tm']]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  10%|████▏                                       | 4/42 [00:00<00:01, 36.58it/s]
# AdaBoostRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# BayesianRidge model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# ElasticNetCV model failed to execute
# For multi-task outputs, use MultiTaskElasticNetCV
#  21%|█████████▍                                  | 9/42 [00:00<00:01, 17.17it/s]
# GammaRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# GradientBoostingRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# HistGradientBoostingRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# HuberRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
#  40%|█████████████████▍                         | 17/42 [00:00<00:01, 20.19it/s]
# LarsCV model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# LassoCV model failed to execute
# For multi-task outputs, use MultiTaskLassoCV
# LassoLarsCV model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# LassoLarsIC model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# LinearSVR model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
#  62%|██████████████████████████▌                | 26/42 [00:01<00:00, 22.24it/s]
# NuSVR model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# OrthogonalMatchingPursuitCV model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# PassiveAggressiveRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# PoissonRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# QuantileRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# RANSACRegressor model failed to execute
# `min_samples` may not be larger than number of samples: n_samples = 39.
#  81%|██████████████████████████████████▊        | 34/42 [00:01<00:00, 17.31it/s]
# SGDRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# SVR model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# TweedieRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
# 100%|███████████████████████████████████████████| 42/42 [00:02<00:00, 20.19it/s]
# LGBMRegressor model failed to execute
# y should be a 1d array, got an array of shape (39, 2) instead.
#                                        Adjusted R-Squared  \
# Model
# Lars                       752859799534714965588967424.00
# KernelRidge                                          4.56
# GaussianProcessRegressor                             4.51
# OrthogonalMatchingPursuit                            1.57
# MLPRegressor                                         1.34
# TransformedTargetRegressor                           1.09
# LinearRegression                                     1.09
# Ridge                                                1.09
# RidgeCV                                              1.07
# ExtraTreeRegressor                                   1.06
# DecisionTreeRegressor                                1.04
# XGBRegressor                                         1.04
# KNeighborsRegressor                                  1.03
# BaggingRegressor                                     1.03
# ElasticNet                                           1.03
# ExtraTreesRegressor                                  1.03
# LassoLars                                            1.03
# Lasso                                                1.03
# RandomForestRegressor                                1.03
# DummyRegressor                                       1.02
#
#                                                    R-Squared  \
# Model
# Lars                       -36806479088363846304998096896.00
# KernelRidge                                          -172.82
# GaussianProcessRegressor                             -170.83
# OrthogonalMatchingPursuit                             -26.77
# MLPRegressor                                          -15.83
# TransformedTargetRegressor                             -3.51
# LinearRegression                                       -3.51
# Ridge                                                  -3.37
# RidgeCV                                                -2.46
# ExtraTreeRegressor                                     -1.98
# DecisionTreeRegressor                                  -0.83
# XGBRegressor                                           -0.74
# KNeighborsRegressor                                    -0.54
# BaggingRegressor                                       -0.52
# ElasticNet                                             -0.51
# ExtraTreesRegressor                                    -0.30
# LassoLars                                              -0.28
# Lasso                                                  -0.28
# RandomForestRegressor                                  -0.23
# DummyRegressor                                         -0.09
#
#                                          RMSE  Time Taken
# Model
# Lars                       742538127977273.00        0.28
# KernelRidge                             53.91        0.01
# GaussianProcessRegressor                53.61        0.01
# OrthogonalMatchingPursuit               21.46        0.02
# MLPRegressor                            16.74        0.28
# TransformedTargetRegressor               8.55        0.02
# LinearRegression                         8.55        0.01
# Ridge                                    8.42        0.01
# RidgeCV                                  7.48        0.01
# ExtraTreeRegressor                       6.87        0.01
# DecisionTreeRegressor                    5.31        0.02
# XGBRegressor                             5.29        0.19
# KNeighborsRegressor                      4.93        0.01
# BaggingRegressor                         4.91        0.07
# ElasticNet                               4.92        0.02
# ExtraTreesRegressor                      4.56        0.33
# LassoLars                                4.54        0.01
# Lasso                                    4.54        0.01
# RandomForestRegressor                    4.43        0.57
# DummyRegressor                           4.17        0.01

# %% [markdown]
# #### Using 7 APRs, RMSF 442 residues and one Y variable

# %%
# Select the columns as predictor variables (X)

X = rmsf_sasa_agg.drop(['sum_aprsasa','Tm','ln(v)'],axis = 1)

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = rmsf_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  21%|█████████▍                                  | 9/42 [00:09<00:37,  1.15s/it]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  62%|██████████████████████████▌                | 26/42 [00:16<00:07,  2.25it/s]
# LassoLarsIC model failed to execute
# You are using LassoLarsIC in the case where the number of samples is smaller than the number of features. In this setting, getting a good estimate for the variance of the noise is not possible. Provide an estimate of the noise variance in the constructor.
#  76%|████████████████████████████████▊          | 32/42 [00:16<00:02,  4.48it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# RANSACRegressor model failed to execute
# `min_samples` may not be larger than number of samples: n_samples = 39.
# 100%|███████████████████████████████████████████| 42/42 [00:17<00:00,  2.45it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.057444
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                          Adjusted R-Squared  \
# Model
# Lars                          42322976509589019412135936.00
# LarsCV                        42322976509589019412135936.00
# SGDRegressor                                           1.18
# OrthogonalMatchingPursuit                              1.10
# HuberRegressor                                         1.05
# TransformedTargetRegressor                             1.05
# LinearRegression                                       1.05
# LinearSVR                                              1.05
# DecisionTreeRegressor                                  1.05
# KernelRidge                                            1.05
# Ridge                                                  1.05
# PassiveAggressiveRegressor                             1.05
# RidgeCV                                                1.04
# QuantileRegressor                                      1.04
# TweedieRegressor                                       1.03
# KNeighborsRegressor                                    1.03
# AdaBoostRegressor                                      1.03
# MLPRegressor                                           1.03
# BaggingRegressor                                       1.03
# OrthogonalMatchingPursuitCV                            1.03
# SVR                                                    1.03
# ExtraTreeRegressor                                     1.02
# ElasticNet                                             1.02
# GradientBoostingRegressor                              1.02
# XGBRegressor                                           1.02
# RandomForestRegressor                                  1.02
# LassoLars                                              1.02
# Lasso                                                  1.02
# GaussianProcessRegressor                               1.02
# LassoLarsCV                                            1.02
# LassoCV                                                1.02
# HistGradientBoostingRegressor                          1.02
# ElasticNetCV                                           1.02
# DummyRegressor                                         1.02
# LGBMRegressor                                          1.02
# NuSVR                                                  1.02
# BayesianRidge                                          1.02
# ExtraTreesRegressor                                    1.02
#
#                                                      R-Squared  \
# Model
# Lars                          -2069123296024352182316826624.00
# LarsCV                        -2069123296024352182316826624.00
# SGDRegressor                                             -7.82
# OrthogonalMatchingPursuit                                -3.75
# HuberRegressor                                           -1.55
# TransformedTargetRegressor                               -1.55
# LinearRegression                                         -1.55
# LinearSVR                                                -1.55
# DecisionTreeRegressor                                    -1.54
# KernelRidge                                              -1.51
# Ridge                                                    -1.50
# PassiveAggressiveRegressor                               -1.49
# RidgeCV                                                  -1.15
# QuantileRegressor                                        -0.74
# TweedieRegressor                                         -0.67
# KNeighborsRegressor                                      -0.67
# AdaBoostRegressor                                        -0.60
# MLPRegressor                                             -0.49
# BaggingRegressor                                         -0.37
# OrthogonalMatchingPursuitCV                              -0.27
# SVR                                                      -0.26
# ExtraTreeRegressor                                       -0.21
# ElasticNet                                               -0.14
# GradientBoostingRegressor                                -0.10
# XGBRegressor                                             -0.09
# RandomForestRegressor                                    -0.07
# LassoLars                                                -0.03
# Lasso                                                    -0.03
# GaussianProcessRegressor                                 -0.03
# LassoLarsCV                                              -0.02
# LassoCV                                                  -0.02
# HistGradientBoostingRegressor                            -0.02
# ElasticNetCV                                             -0.02
# DummyRegressor                                           -0.02
# LGBMRegressor                                            -0.02
# NuSVR                                                    -0.01
# BayesianRidge                                             0.02
# ExtraTreesRegressor                                       0.10
#
#                                             RMSE  Time Taken
# Model
# Lars                          175911719003800.28        0.13
# LarsCV                        175911719003800.28        0.75
# SGDRegressor                               11.49        0.01
# OrthogonalMatchingPursuit                   8.42        0.01
# HuberRegressor                              6.18        0.04
# TransformedTargetRegressor                  6.17        0.01
# LinearRegression                            6.17        0.01
# LinearSVR                                   6.17        0.02
# DecisionTreeRegressor                       6.16        0.02
# KernelRidge                                 6.13        0.01
# Ridge                                       6.11        0.01
# PassiveAggressiveRegressor                  6.10        0.02
# RidgeCV                                     5.67        0.01
# QuantileRegressor                           5.10        0.03
# TweedieRegressor                            4.99        0.02
# KNeighborsRegressor                         4.99        0.01
# AdaBoostRegressor                           4.89        0.18
# MLPRegressor                                4.72        0.16
# BaggingRegressor                            4.52        0.07
# OrthogonalMatchingPursuitCV                 4.35        0.02
# SVR                                         4.35        0.01
# ExtraTreeRegressor                          4.26        0.01
# ElasticNet                                  4.13        0.01
# GradientBoostingRegressor                   4.06        0.49
# XGBRegressor                                4.04        0.10
# RandomForestRegressor                       4.00        0.54
# LassoLars                                   3.92        0.01
# Lasso                                       3.92        0.01
# GaussianProcessRegressor                    3.92        0.01
# LassoLarsCV                                 3.91        0.06
# LassoCV                                     3.91        4.76
# HistGradientBoostingRegressor               3.91        0.10
# ElasticNetCV                                3.91        9.03
# DummyRegressor                              3.91        0.01
# LGBMRegressor                               3.91        0.02
# NuSVR                                       3.89        0.01
# BayesianRidge                               3.82        0.02
# ExtraTreesRegressor                         3.66        0.31

# %% [markdown]
# ### Using 7 APRs, mean RMSF and one Y variable

# %%
# Read SASA of 7 APR data from the excel 
sasa_apr = pd.read_excel("SASA_7APRs_54conditions231023.xlsx",index_col=0)

# read the excel data of the mean rmsf and their aggregation rates

mean_rmsf = pd.read_excel("mean_rmsf_agg.xlsx",index_col=0)

# add a column of the sum of SASA of all APRs
sasa_apr["sum_aprsasa"] = sasa_apr.sum(axis = 1)

mean_rmsf_sasa_agg = pd.concat([sasa_apr,mean_rmsf],axis=1,join='inner')

# %% [markdown]
# #### 7 APRs, mean RMSF

# %%
# Select the columns as predictor variables (X)

X = mean_rmsf_sasa_agg.drop(['sum_aprsasa','Tm','ln(v)'],axis = 1)

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_sasa_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  31%|█████████████▎                             | 13/42 [00:00<00:00, 47.53it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  81%|██████████████████████████████████▊        | 34/42 [00:00<00:00, 67.22it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 66.28it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# AdaBoostRegressor                           -3.21       0.53  1.86        0.05
# OrthogonalMatchingPursuitCV                 -3.42       0.51  1.90        0.01
# OrthogonalMatchingPursuit                   -3.42       0.51  1.90        0.01
# LassoCV                                     -4.08       0.44  2.04        0.03
# LarsCV                                      -4.08       0.44  2.04        0.01
# LassoLarsCV                                 -4.08       0.44  2.04        0.01
# LassoLarsIC                                 -4.15       0.43  2.05        0.01
# LassoLars                                   -4.24       0.42  2.07        0.00
# Lasso                                       -4.24       0.42  2.07        0.00
# GradientBoostingRegressor                   -4.91       0.34  2.20        0.03
# XGBRegressor                                -5.08       0.32  2.23        0.07
# RandomForestRegressor                       -5.11       0.32  2.24        0.07
# KernelRidge                                 -5.21       0.31  2.25        0.00
# ExtraTreesRegressor                         -5.70       0.26  2.34        0.05
# LinearSVR                                   -6.15       0.21  2.42        0.00
# ElasticNetCV                                -6.30       0.19  2.44        0.04
# DecisionTreeRegressor                       -6.48       0.17  2.48        0.00
# BaggingRegressor                            -6.64       0.15  2.50        0.02
# HuberRegressor                              -6.71       0.14  2.51        0.01
# Lars                                        -7.18       0.09  2.59        0.01
# LinearRegression                            -7.18       0.09  2.59        0.00
# TransformedTargetRegressor                  -7.18       0.09  2.59        0.00
# GaussianProcessRegressor                    -7.37       0.07  2.62        0.01
# Ridge                                       -7.37       0.07  2.62        0.00
# SVR                                         -7.56       0.05  2.65        0.00
# SGDRegressor                                -7.63       0.04  2.66        0.00
# BayesianRidge                               -7.97       0.00  2.71        0.00
# NuSVR                                       -8.69      -0.08  2.82        0.00
# PassiveAggressiveRegressor                  -8.91      -0.10  2.85        0.00
# RidgeCV                                     -8.97      -0.11  2.86        0.00
# KNeighborsRegressor                         -9.00      -0.11  2.86        0.01
# ElasticNet                                  -9.54      -0.17  2.94        0.00
# RANSACRegressor                            -10.49      -0.28  3.07        0.02
# TweedieRegressor                           -11.65      -0.41  3.22        0.01
# MLPRegressor                               -11.66      -0.41  3.22        0.04
# ExtraTreeRegressor                         -12.87      -0.54  3.37        0.01
# LGBMRegressor                              -21.16      -1.46  4.26        0.01
# HistGradientBoostingRegressor              -21.16      -1.46  4.26        0.05
# DummyRegressor                             -21.16      -1.46  4.26        0.00
# QuantileRegressor                          -25.81      -1.98  4.69        0.01

# %% [markdown]
# #### Using sum value of 7 APRs, mean RMSF, one variable Y lnv

# %%
mean_rmsf_sasa_agg
# Out:
#               r_31-36  r_47-51  r_114-118  r_129-139  r_261-265  r_325-329  \
# 3_5_277_0        0.37     0.02       0.25       0.18      -0.11       0.07
# 8_338_0          0.71     0.57       0.32       0.15       0.58       0.54
# 3_5_338_100      0.61     0.44       0.87       1.05       0.09       0.14
# 3_5_338_200      1.13     0.58       0.48       0.85       0.65       0.56
# 5_5_296_250      0.28     0.09       0.08       0.49       0.27       0.18
# 9_338_200        1.05     0.47       0.25       0.76       0.28       0.41
# 318K_7_250M      0.73     0.45       0.29       0.21       0.31       0.27
# 3_5_277_50       0.37     0.24       0.10       0.13       0.10      -0.05
# 296K_7_50M       0.15     0.08       0.11      -0.21       0.25       0.08
# 4_5_296_250      0.66     0.29       0.44       0.50       0.34       0.39
# 318_4_5_150M     0.21    -0.06      -0.10       0.03      -0.10       0.01
# 7_296_250        0.62     0.38      -0.05       0.04       0.22      -0.04
# 8_338_500        0.89     0.53       0.48       0.36       0.19       0.26
# 7_338_0          1.17     0.61       0.61       0.96       0.63       0.44
# 9_338_100        0.81     0.67       0.74       1.23       0.81       0.68
# 277_3_5_150M     0.15     0.17       0.11       0.11       0.08      -0.04
# 3_5_338_250      0.79     0.55       0.30       0.81       0.48       0.47
# 9_338_500        1.22     0.57       0.68       0.95       0.60       0.29
# 3_5_338_150      0.44     0.10       0.24       0.48       0.23       0.13
# 5_5_296_100      0.51    -0.00       0.31       0.16      -0.15       0.23
# 4_5_338_0        0.80     0.39       0.17       0.37       0.53       0.47
# 4_5_338_200      1.00     0.54       0.94       1.74       0.20       0.66
# 9_338_400        0.61     0.35       0.53       0.79       0.48       0.32
# 338_4_5_250M     0.28    -0.07      -0.23       0.16      -0.16       0.18
# 4_5_338_200        2.04         7.12       0.18 71.89   7.09
# 9_338_400          0.67         3.76       0.18 76.80   2.86
# 338_4_5_250M       0.05         0.20       0.18 73.07   6.85
# 9_338_0            0.92         3.24       0.17 76.50   2.06
# 5_5_296_0         -0.08         0.80       0.14 79.61  -2.96
# 8_338_400          0.09         3.27       0.18 77.25   2.05
# 5_5_296_200       -0.06         0.57       0.14 80.33  -3.70
# 318K_7_150M        0.53         2.72       0.16 78.63  -2.81
# 338K_7_50M         1.70         6.17       0.20 77.97   0.98
# 9_338_300          0.96         3.49       0.17 76.94   2.83
# 8_277_100          0.07         1.19       0.14 77.35  -4.82
# 8_338_300          1.18         4.39       0.18 77.85   2.08
# 318_4_5_50M        0.26        -0.18       0.16 75.00  -3.20
# 338_3_5_50M        0.19         2.83       0.18 64.95   9.32
# 5_5_296_150        0.24         1.63       0.14 80.36  -4.09
# 5_5_296_50         0.52         2.76       0.14 79.71  -3.61
# 277K_7_250M        0.22         2.22       0.13 77.93  -4.86
# 318_3_5_250M       0.08         2.26       0.16 59.52   1.38
# 7_296_50           0.31         2.62       0.14 77.97  -4.65
# 296_4_5_50M        0.08         0.52       0.13 75.00  -4.12
# 4_5_338_50         1.40         5.28       0.18 75.00   4.90
# 277K_7_150M        1.05         3.52       0.14 78.63  -5.32
# 296_3_5_250M       0.23         1.14       0.15 59.52  -3.81
# 4_5_338_100        1.20         3.95       0.18 73.96   5.60
# 7_296_150          0.84         3.38       0.14 78.63  -4.02
# 8_338_200          0.45         3.44       0.18 77.94   2.18
# 4_5_338_150        2.40         8.95       0.18 73.31   6.54
# 277_4_5_250M      -0.20        -0.11       0.13 73.07  -3.59

# %%
# Select the columns as predictor variables (X)

X = mean_rmsf_sasa_agg[['sum_aprsasa','mean RMSF']]

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_sasa_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  31%|█████████████▎                             | 13/42 [00:00<00:00, 47.34it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  81%|██████████████████████████████████▊        | 34/42 [00:00<00:00, 71.46it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 67.09it/s]
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.58       0.67  1.56        0.00
# KernelRidge                                  0.50       0.61  1.69        0.00
# BaggingRegressor                             0.38       0.52  1.88        0.02
# DecisionTreeRegressor                        0.37       0.51  1.90        0.00
# OrthogonalMatchingPursuitCV                  0.37       0.51  1.90        0.01
# OrthogonalMatchingPursuit                    0.37       0.51  1.90        0.01
# RandomForestRegressor                        0.31       0.46  1.99        0.07
# LassoLars                                    0.27       0.43  2.05        0.00
# Lasso                                        0.27       0.43  2.05        0.00
# ExtraTreesRegressor                          0.23       0.40  2.11        0.05
# LinearSVR                                    0.22       0.39  2.11        0.00
# XGBRegressor                                 0.21       0.39  2.12        0.08
# LassoCV                                      0.20       0.38  2.14        0.03
# AdaBoostRegressor                            0.19       0.37  2.15        0.05
# LarsCV                                       0.19       0.37  2.16        0.01
# LassoLarsIC                                  0.19       0.37  2.16        0.00
# LassoLarsCV                                  0.19       0.37  2.16        0.01
# Lars                                         0.19       0.37  2.16        0.01
# LinearRegression                             0.19       0.37  2.16        0.00
# TransformedTargetRegressor                   0.19       0.37  2.16        0.00
# GradientBoostingRegressor                    0.19       0.37  2.16        0.03
# ElasticNetCV                                 0.18       0.36  2.17        0.03
# HuberRegressor                               0.17       0.36  2.18        0.01
# RidgeCV                                      0.17       0.36  2.18        0.00
# Ridge                                        0.17       0.36  2.18        0.00
# BayesianRidge                                0.17       0.35  2.18        0.01
# KNeighborsRegressor                          0.16       0.35  2.20        0.00
# SGDRegressor                                 0.11       0.31  2.25        0.00
# MLPRegressor                                 0.08       0.29  2.29        0.04
# NuSVR                                       -0.02       0.21  2.42        0.01
# ExtraTreeRegressor                          -0.05       0.18  2.46        0.01
# ElasticNet                                  -0.17       0.09  2.59        0.00
# PassiveAggressiveRegressor                  -0.17       0.09  2.59        0.00
# RANSACRegressor                             -0.25       0.03  2.68        0.01
# TweedieRegressor                            -0.33      -0.04  2.76        0.01
# LGBMRegressor                               -2.17      -1.46  4.26        0.01
# DummyRegressor                              -2.17      -1.46  4.26        0.00
# HistGradientBoostingRegressor               -2.17      -1.46  4.26        0.06
# QuantileRegressor                           -2.83      -1.98  4.69        0.01
# GaussianProcessRegressor                 -1261.19    -980.70 85.07        0.01

# %% [markdown]
# # Native contacts, SASA, RMSF vs lnv

# %% [markdown]
# ##### clean the nc dataframe to make it under cleaned condition names, not need to run again. Reading the excel file directly below - no use anymore. The native contacts used here is actually the fraction of salt bridges

# %%
import re 
import pandas as pd
import numpy as np

# Read SASA of 7 APR data from the excel 
sasa_apr = pd.read_excel("SASA_7APRs_54conditions231023.xlsx",index_col=0)

# read the excel data of the rmsf of 442 residues and their aggregation rates

rmsf_agg = pd.read_excel("rmsf_442residues_agg.xlsx",index_col=0)

# add a column of the sum of SASA of all APRs
sasa_apr["sum_aprsasa"] = sasa_apr.sum(axis = 1)

# Read the 54 condition names
run54 = pd.read_excel("54ConditionName120923.xlsx",index_col=0)


# Read Native contacts from the excel
nc = pd.read_excel("54DCDNativeContact311023.xlsx",index_col = 1)
nc = nc.drop(nc.columns[0],axis=1)

# clean the nc dataframe to make it under cleaned condition names
# average the replicas

nc_avg = []

for i in list(run54['Condition']):
    
    avg = []
    
    # loop over the rows in a dataframe
    for index, row in nc.iterrows():
        
        # search for any matching
        if re.search(i,index):
            
            data = row['Average native contact (last 50ns)']
            
            avg.append(data)
            
    # calculate the mean value of the six replicas for each condition
    avg = np.mean(avg)
    
    # append the condition info as well as the calculated mean native contacts into a list
    nc_avg.append([i,avg])
    
    
    
# convert the list to a dataframe   
df_nc_avg = pd.DataFrame(nc_avg)

# assign column names
df_nc_avg.columns = ['Condition','Average native contact (last 50ns)']

nc_updated = df_nc_avg

# Write the new dataframe into an excel file
#nc_updated.to_excel("nc_updated311023.xlsx")

# %% [markdown]
# ### 061123 Updated native contact version

# %% [markdown]
# ##### updated version of native contacts, 06/11/23, after using alpha carbon to calculate the native contacts instead of the salt bridges, this version seems much better

# %%
import re 
import pandas as pd
import numpy as np

# Read the 54 condition names
run54 = pd.read_excel("54ConditionName120923.xlsx",index_col=0)

# Read Native contacts from the excel
nc = pd.read_excel("NativeContacts_AlphaCarbon061123.xlsx",index_col = 0)

# clean the nc dataframe to make it under cleaned condition names
# average the replicas

nc_avg = []

for i in list(run54['Condition']):
    
    avg = []
    
    # loop over the rows in a dataframe
    for index, row in nc.iterrows():
        
        # search for any matching
        if re.search(i,index):
            
            data = row['Average native contact (last 50ns)']
            
            avg.append(data)
            
    # calculate the mean value of the six replicas for each condition
    avg = np.mean(avg)
    
    # append the condition info as well as the calculated mean native contacts into a list
    nc_avg.append([i,avg])
    
    
    
# convert the list to a dataframe   
df_nc_avg = pd.DataFrame(nc_avg)

# assign column names
df_nc_avg.columns = ['Condition','Average native contact (last 50ns)']

nc_updated = df_nc_avg

# Write the new dataframe into an excel file
#nc_updated.to_excel("nc_updated061123.xlsx")

# %% [markdown]
# #### Read files

# %%
import pandas as pd

# Read SASA of 7 APR data from the excel 
sasa_apr = pd.read_excel("SASA_7APRs_54conditions231023.xlsx",index_col=0)

# read the excel data of the rmsf of 442 residues and their aggregation rates

rmsf_agg = pd.read_excel("rmsf_442residues_agg.xlsx",index_col=0)

# add a column of the sum of SASA of all APRs
sasa_apr["sum_aprsasa"] = sasa_apr.sum(axis = 1)

# Read the 54 condition names
run54 = pd.read_excel("54ConditionName120923.xlsx",index_col=0)


# Read Native contacts from the excel, set the condition column as the index column 
nc = pd.read_excel("nc_updated061123.xlsx",index_col = 1)

# Drop the first column
nc = nc.drop(nc.columns[0],axis=1)

# join all the three features (nc, sasa_apr, rmsf_agg) together into one dataframe
rmsf_sasa_nc_agg = pd.concat([nc,sasa_apr,rmsf_agg],axis=1,join='inner')

# save the joined dataframe into an excel
#rmsf_sasa_nc_agg.to_excel("rmsf_sasa_nc_agg061123.xlsx")

# read the excel data of the mean rmsf and their aggregation rates

mean_rmsf = pd.read_excel("mean_rmsf_agg.xlsx",index_col=0)

# join the dataframes
mean_rmsf_nc_sasa_agg = pd.concat([nc,sasa_apr,mean_rmsf],axis=1,join='inner')

# save the dataframe to an excel file
#mean_rmsf_nc_sasa_agg.to_excel("mean_rmsf_nc_sasa_agg061123.xlsx")

# %%
rmsf_sasa_nc_agg
# Out:
#               Average native contact (last 50ns)   r_31-36   r_47-51  \
# 3_5_277_0                               0.820499  0.372220  0.023772
# 8_338_0                                 0.813804  0.705146  0.574838
# 3_5_338_100                             0.814145  0.613732  0.438593
# 3_5_338_200                             0.810917  1.129000  0.583300
# 5_5_296_250                             0.820969  0.284520  0.088570
# 9_338_200                               0.814184  1.047581  0.471270
# 318K_7_250M                             0.818584  0.729646  0.450002
# 3_5_277_50                              0.821139  0.373968  0.244099
# 296K_7_50M                              0.818804  0.150209  0.082233
# 4_5_296_250                             0.817770  0.661202  0.293401
# 318_4_5_150M                            0.900903  0.214288 -0.063994
# 7_296_250                               0.821279  0.615936  0.384994
# 8_338_500                               0.813417  0.885452  0.531798
# 7_338_0                                 0.815808  1.166540  0.613555
# 9_338_100                               0.815564  0.812380  0.668912
# 277_3_5_150M                            0.821528  0.147361  0.167100
# 3_5_338_250                             0.813499  0.787662  0.554409
# 296_3_5_250M  0.628083  0.625583  0.774650  0.871133  1.043283  59.523900
# 4_5_338_100   0.419983  0.443100  0.481233  0.583617  0.681233  73.955500
# 7_296_150     0.539050  0.594600  0.751500  0.908367  1.086067  78.629833
# 8_338_200     0.453000  0.532983  0.595717  0.665283  0.781083  77.940967
# 4_5_338_150   0.511850  0.574667  0.629683  0.745417  0.903467  73.311600
# 277_4_5_250M  0.444867  0.523550  0.635117  0.798567  0.964967  73.072700
#
#                  ln(v)
# 3_5_277_0    -5.945103
# 8_338_0       1.616794
# 3_5_338_100   9.005473
# 3_5_338_200   9.639418
# 5_5_296_250  -3.761981
# 9_338_200     2.465767
# 318K_7_250M  -2.707400
# 3_5_277_50   -4.382091
# 296K_7_50M   -4.651000
# 4_5_296_250  -4.193857
# 318_4_5_150M -3.073900
# 7_296_250    -6.083580
# 8_338_500     1.832447
# 7_338_0       0.981778
# 9_338_100     2.835914
# 277_3_5_150M -5.361700
# 3_5_338_250   9.878259
# 9_338_500     2.800305
# 3_5_338_150   9.593252
# 5_5_296_100  -3.675797
# 4_5_338_0     0.430820
# 4_5_338_200   7.094788
# 9_338_400     2.855701
# 338_4_5_250M  6.852800
# 9_338_0       2.060694
# 5_5_296_0    -2.958218
# 8_338_400     2.053706
# 5_5_296_200  -3.699562
# 318K_7_150M  -2.806800
# 338K_7_50M    0.983300
# 9_338_300     2.827034
# 8_277_100    -4.823917
# 8_338_300     2.079565
# 318_4_5_50M  -3.202900
# 338_3_5_50M   9.317400
# 5_5_296_150  -4.092552
# 5_5_296_50   -3.605309
# 277K_7_250M  -4.860800
# 318_3_5_250M  1.376900
# 7_296_50     -4.651002
# 296_4_5_50M  -4.123900
# 4_5_338_50    4.900827
# 277K_7_150M  -5.324000
# 296_3_5_250M -3.813900
# 4_5_338_100   5.599474
# 7_296_150    -4.024684
# 8_338_200     2.182835
# 4_5_338_150   6.544445
# 277_4_5_250M -3.586700
#
# [49 rows x 453 columns]

# %% [markdown]
# #### Using 7 APRs, RMSF442 residues, nc, one variable Y

# %%
# Select the columns as predictor variables (X)

X = rmsf_sasa_nc_agg.drop(['sum_aprsasa','Tm','ln(v)'],axis = 1)

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = rmsf_sasa_nc_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  21%|█████████▍                                  | 9/42 [00:03<00:13,  2.53it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  55%|███████████████████████▌                   | 23/42 [00:06<00:05,  3.22it/s]
# LassoLarsIC model failed to execute
# You are using LassoLarsIC in the case where the number of samples is smaller than the number of features. In this setting, getting a good estimate for the variance of the noise is not possible. Provide an estimate of the noise variance in the constructor.
#  76%|████████████████████████████████▊          | 32/42 [00:07<00:01,  7.37it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# RANSACRegressor model failed to execute
# `min_samples` may not be larger than number of samples: n_samples = 39.
# 100%|███████████████████████████████████████████| 42/42 [00:08<00:00,  5.04it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                              Adjusted R-Squared  \
# Model
# Lars                          576692419464267177082237222912.00
# OrthogonalMatchingPursuit                                  1.06
# QuantileRegressor                                          1.06
# HistGradientBoostingRegressor                              1.05
# DummyRegressor                                             1.05
# LGBMRegressor                                              1.05
# GaussianProcessRegressor                                   1.04
# OrthogonalMatchingPursuitCV                                1.02
# SGDRegressor                                               1.02
# XGBRegressor                                               1.02
# LarsCV                                                     1.02
# HuberRegressor                                             1.02
# LinearSVR                                                  1.02
# LinearRegression                                           1.02
# TransformedTargetRegressor                                 1.02
# Ridge                                                      1.02
# PassiveAggressiveRegressor                                 1.02
# MLPRegressor                                               1.02
# RidgeCV                                                    1.01
# KernelRidge                                                1.01
# TweedieRegressor                                           1.01
# ExtraTreesRegressor                                        1.01
# GradientBoostingRegressor                                  1.01
# BayesianRidge                                              1.01
# KNeighborsRegressor                                        1.01
# RandomForestRegressor                                      1.01
# LassoLars                                                  1.01
# Lasso                                                      1.01
# NuSVR                                                      1.01
# LassoLarsCV                                                1.01
# LassoCV                                                    1.01
# DecisionTreeRegressor                                      1.01
# ElasticNet                                                 1.01
# ElasticNetCV                                               1.01
# ExtraTreeRegressor                                         1.01
# BaggingRegressor                                           1.00
# SVR                                                        1.00
# AdaBoostRegressor                                          1.00
#
#                                                          R-Squared  \
# Model
# Lars                          -28257928553749094421410646851584.00
# OrthogonalMatchingPursuit                                    -2.06
# QuantileRegressor                                            -1.98
# HistGradientBoostingRegressor                                -1.46
# DummyRegressor                                               -1.46
# LGBMRegressor                                                -1.46
# GaussianProcessRegressor                                     -0.81
# OrthogonalMatchingPursuitCV                                  -0.22
# SGDRegressor                                                 -0.16
# XGBRegressor                                                 -0.11
# LarsCV                                                        0.05
# HuberRegressor                                                0.13
# LinearSVR                                                     0.13
# LinearRegression                                              0.13
# TransformedTargetRegressor                                    0.13
# Ridge                                                         0.15
# PassiveAggressiveRegressor                                    0.19
# MLPRegressor                                                  0.23
# RidgeCV                                                       0.27
# KernelRidge                                                   0.28
# TweedieRegressor                                              0.37
# ExtraTreesRegressor                                           0.44
# GradientBoostingRegressor                                     0.45
# BayesianRidge                                                 0.45
# KNeighborsRegressor                                           0.45
# RandomForestRegressor                                         0.53
# LassoLars                                                     0.55
# Lasso                                                         0.55
# NuSVR                                                         0.55
# LassoLarsCV                                                   0.57
# LassoCV                                                       0.58
# DecisionTreeRegressor                                         0.58
# ElasticNet                                                    0.60
# ElasticNetCV                                                  0.60
# ExtraTreeRegressor                                            0.74
# BaggingRegressor                                              0.76
# SVR                                                           0.79
# AdaBoostRegressor                                             0.93
#
#                                               RMSE  Time Taken
# Model
# Lars                          14432373703680722.00        0.14
# OrthogonalMatchingPursuit                     4.75        0.01
# QuantileRegressor                             4.69        0.13
# HistGradientBoostingRegressor                 4.26        0.13
# DummyRegressor                                4.26        0.01
# LGBMRegressor                                 4.26        0.09
# GaussianProcessRegressor                      3.65        0.02
# OrthogonalMatchingPursuitCV                   2.99        0.03
# SGDRegressor                                  2.92        0.01
# XGBRegressor                                  2.87        0.11
# LarsCV                                        2.65        0.64
# HuberRegressor                                2.54        0.05
# LinearSVR                                     2.54        0.02
# LinearRegression                              2.54        0.02
# TransformedTargetRegressor                    2.54        0.01
# Ridge                                         2.50        0.01
# PassiveAggressiveRegressor                    2.44        0.02
# MLPRegressor                                  2.39        0.32
# RidgeCV                                       2.32        0.01
# KernelRidge                                   2.30        0.01
# TweedieRegressor                              2.16        0.02
# ExtraTreesRegressor                           2.03        0.31
# GradientBoostingRegressor                     2.02        0.49
# 296_3_5_250M       0.44       0.25       0.16       0.23         1.14
# 4_5_338_100        0.34       0.27       0.37       1.20         3.95
# 7_296_150          0.57       0.16       0.32       0.84         3.38
# 8_338_200          0.74       0.39       0.01       0.45         3.44
# 4_5_338_150        1.59       0.76       0.72       2.40         8.95
# 277_4_5_250M      -0.26       0.19      -0.01      -0.20        -0.11
#
#               mean RMSF    Tm  ln(v)
# 3_5_277_0          0.14 73.70  -5.95
# 8_338_0            0.18 77.89   1.62
# 3_5_338_100        0.18 62.48   9.01
# 3_5_338_200        0.19 60.65   9.64
# 5_5_296_250        0.14 80.72  -3.76
# 9_338_200          0.17 77.35   2.47
# 318K_7_250M        0.16 77.93  -2.71
# 3_5_277_50         0.13 64.95  -4.38
# 296K_7_50M         0.15 77.97  -4.65
# 4_5_296_250        0.15 73.07  -4.19
# 318_4_5_150M       0.16 73.31  -3.07
# 7_296_250          0.14 77.93  -6.08
# 8_338_500          0.19 77.11   1.83
# 7_338_0            0.17 78.45   0.98
# 9_338_100          0.17 76.66   2.84
# 277_3_5_150M       0.13 61.85  -5.36
# 3_5_338_250        0.18 59.52   9.88
# 9_338_500          0.18 76.82   2.80
# 3_5_338_150        0.18 61.85   9.59
# 5_5_296_100        0.15 81.31  -3.68
# 4_5_338_0          0.18 83.17   0.43
# 4_5_338_200        0.18 71.89   7.09
# 9_338_400          0.18 76.80   2.86
# 338_4_5_250M       0.18 73.07   6.85
# 9_338_0            0.17 76.50   2.06
# 5_5_296_0          0.14 79.61  -2.96
# 8_338_400          0.18 77.25   2.05
# 5_5_296_200        0.14 80.33  -3.70
# 318K_7_150M        0.16 78.63  -2.81
# 338K_7_50M         0.20 77.97   0.98
# 9_338_300          0.17 76.94   2.83
# 8_277_100          0.14 77.35  -4.82
# 8_338_300          0.18 77.85   2.08
# 318_4_5_50M        0.16 75.00  -3.20
# 338_3_5_50M        0.18 64.95   9.32
# 5_5_296_150        0.14 80.36  -4.09
# 5_5_296_50         0.14 79.71  -3.61
# 277K_7_250M        0.13 77.93  -4.86
# 318_3_5_250M       0.16 59.52   1.38
# 7_296_50           0.14 77.97  -4.65
# 296_4_5_50M        0.13 75.00  -4.12
# 4_5_338_50         0.18 75.00   4.90
# 277K_7_150M        0.14 78.63  -5.32
# 296_3_5_250M       0.15 59.52  -3.81
# 4_5_338_100        0.18 73.96   5.60
# 7_296_150          0.14 78.63  -4.02
# 8_338_200          0.18 77.94   2.18
# 4_5_338_150        0.18 73.31   6.54
# 277_4_5_250M       0.13 73.07  -3.59

# %%
# read the excel data of the mean rmsf and their aggregation rates

mean_rmsf = pd.read_excel("mean_rmsf_nc_sasa_agg061123.xlsx",index_col=0)

# Select the columns as predictor variables (X)

X = mean_rmsf_nc_sasa_agg[['Average native contact (last 50ns)','sum_aprsasa','mean RMSF']]

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_nc_sasa_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  33%|██████████████▎                            | 14/42 [00:00<00:00, 52.79it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 68.80it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreeRegressor                           0.67       0.78  1.28        0.01
# XGBRegressor                                 0.55       0.70  1.49        0.07
# SVR                                          0.48       0.66  1.59        0.00
# KernelRidge                                  0.46       0.64  1.63        0.00
# OrthogonalMatchingPursuitCV                  0.26       0.51  1.90        0.01
# OrthogonalMatchingPursuit                    0.26       0.51  1.90        0.00
# GradientBoostingRegressor                    0.17       0.45  2.02        0.03
# RandomForestRegressor                        0.15       0.44  2.04        0.07
# LassoLars                                    0.15       0.43  2.05        0.00
# Lasso                                        0.15       0.43  2.05        0.00
# AdaBoostRegressor                            0.13       0.42  2.07        0.04
# LinearSVR                                    0.11       0.40  2.10        0.00
# BaggingRegressor                             0.08       0.39  2.12        0.01
# LarsCV                                       0.07       0.38  2.13        0.01
# LassoLarsCV                                  0.07       0.38  2.13        0.01
# LassoLarsIC                                  0.07       0.38  2.13        0.00
# LassoCV                                      0.07       0.38  2.13        0.04
# Lars                                         0.07       0.38  2.14        0.00
# TransformedTargetRegressor                   0.07       0.38  2.14        0.00
# LinearRegression                             0.07       0.38  2.14        0.00
# ExtraTreesRegressor                          0.06       0.38  2.14        0.05
# HuberRegressor                               0.06       0.37  2.15        0.01
# RidgeCV                                      0.06       0.37  2.15        0.00
# Ridge                                        0.06       0.37  2.15        0.00
# ElasticNetCV                                 0.05       0.37  2.16        0.04
# DecisionTreeRegressor                        0.05       0.37  2.16        0.00
# KNeighborsRegressor                          0.05       0.36  2.16        0.00
# BayesianRidge                                0.04       0.36  2.17        0.00
# SGDRegressor                                 0.00       0.34  2.21        0.00
# MLPRegressor                                -0.11       0.26  2.34        0.04
# NuSVR                                       -0.11       0.26  2.34        0.01
# PassiveAggressiveRegressor                  -0.36       0.09  2.58        0.00
# ElasticNet                                  -0.36       0.09  2.59        0.00
# TweedieRegressor                            -0.53      -0.02  2.74        0.01
# RANSACRegressor                             -0.97      -0.31  3.11        0.01
# LGBMRegressor                               -2.69      -1.46  4.26        0.01
# DummyRegressor                              -2.69      -1.46  4.26        0.00
# HistGradientBoostingRegressor               -2.69      -1.46  4.26        0.05
# QuantileRegressor                           -3.47      -1.98  4.69        0.01
# GaussianProcessRegressor                    -9.58      -6.05  7.21        0.01

# %% [markdown]
# #### 7 APRs, sum of APR, native contacts, mean RMSF

# %%
# read the excel data of the mean rmsf and their aggregation rates

mean_rmsf_nc_sasa_agg = pd.read_excel("mean_rmsf_nc_sasa_agg061123.xlsx",index_col=0)

# Select the columns as predictor variables (X)

X = mean_rmsf_nc_sasa_agg.drop(['Tm','ln(v)'],axis = 1)

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_nc_sasa_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  60%|█████████████████████████▌                 | 25/42 [00:00<00:00, 73.08it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  81%|██████████████████████████████████▊        | 34/42 [00:00<00:00, 63.49it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 62.67it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# QuantileRegressor                           27.81      -1.98  4.69        0.01
# HistGradientBoostingRegressor               23.16      -1.46  4.26        0.05
# DummyRegressor                              23.16      -1.46  4.26        0.00
# LGBMRegressor                               23.16      -1.46  4.26        0.02
# PassiveAggressiveRegressor                  16.57      -0.73  3.57        0.00
# MLPRegressor                                14.05      -0.45  3.27        0.04
# TweedieRegressor                            13.70      -0.41  3.22        0.01
# DecisionTreeRegressor                       11.84      -0.20  2.98        0.00
# ElasticNet                                  11.47      -0.16  2.93        0.00
# RANSACRegressor                             11.34      -0.15  2.91        0.02
# KNeighborsRegressor                         11.12      -0.12  2.88        0.00
# NuSVR                                       11.08      -0.12  2.87        0.01
# RidgeCV                                     10.88      -0.10  2.84        0.00
# TransformedTargetRegressor                  10.52      -0.06  2.79        0.00
# LinearRegression                            10.52      -0.06  2.79        0.00
# Lars                                        10.52      -0.06  2.79        0.01
# BayesianRidge                               10.26      -0.03  2.75        0.01
# Ridge                                       10.25      -0.03  2.75        0.00
# LinearSVR                                   10.18      -0.02  2.74        0.00
# SGDRegressor                                10.10      -0.01  2.73        0.01
# GaussianProcessRegressor                    10.06      -0.01  2.72        0.01
# SVR                                          9.45       0.06  2.63        0.00
# GradientBoostingRegressor                    9.24       0.08  2.60        0.03
# HuberRegressor                               8.89       0.12  2.54        0.01
# BaggingRegressor                             8.88       0.12  2.54        0.02
# ExtraTreesRegressor                          8.54       0.16  2.48        0.05
# AdaBoostRegressor                            8.33       0.19  2.45        0.05
# ElasticNetCV                                 8.30       0.19  2.45        0.04
# ExtraTreeRegressor                           8.14       0.21  2.42        0.01
# KernelRidge                                  8.13       0.21  2.42        0.00
# RandomForestRegressor                        7.86       0.24  2.37        0.07
# XGBRegressor                                 6.85       0.35  2.19        0.08
# LassoLars                                    6.24       0.42  2.07        0.00
# Lasso                                        6.24       0.42  2.07        0.00
# LassoLarsIC                                  6.15       0.43  2.05        0.01
# LassoLarsCV                                  6.08       0.44  2.04        0.01
# LassoCV                                      6.08       0.44  2.04        0.04
# LarsCV                                       6.06       0.44  2.04        0.01
# OrthogonalMatchingPursuitCV                  5.42       0.51  1.90        0.01
# OrthogonalMatchingPursuit                    5.42       0.51  1.90        0.01

# %% [markdown]
# ### old version, nc - salt bridges fraction

# %% [markdown]
# #### Read files

# %%
import pandas as pd

# Read SASA of 7 APR data from the excel 
sasa_apr = pd.read_excel("SASA_7APRs_54conditions231023.xlsx",index_col=0)

# read the excel data of the rmsf of 442 residues and their aggregation rates

rmsf_agg = pd.read_excel("rmsf_442residues_agg.xlsx",index_col=0)

# add a column of the sum of SASA of all APRs
sasa_apr["sum_aprsasa"] = sasa_apr.sum(axis = 1)

# Read the 54 condition names
run54 = pd.read_excel("54ConditionName120923.xlsx",index_col=0)


# Read Native contacts from the excel, set the condition column as the index column 
nc = pd.read_excel("nc_updated311023.xlsx",index_col = 1)

# Drop the first column
nc = nc.drop(nc.columns[0],axis=1)

# join all the three features (nc, sasa_apr, rmsf_agg) together into one dataframe
rmsf_sasa_nc_agg = pd.concat([nc,sasa_apr,rmsf_agg],axis=1,join='inner')

# save the joined dataframe into an excel
#rmsf_sasa_nc_agg.to_excel("rmsf_sasa_nc_agg311023.xlsx")

# %% [markdown]
# #### Using 7 APRs, RMSF442 residues, nc, one variable Y

# %%
rmsf_sasa_nc_agg = pd.read_excel("rmsf_sasa_nc_agg311023.xlsx",index_col=0)
# 5_5_296_200   ... 0.36 0.47 0.50 0.52 0.53 0.63 0.74 0.88 80.33  -3.70
# 318K_7_150M   ... 0.35 0.50 0.50 0.52 0.60 0.65 0.70 0.85 78.63  -2.81
# 338K_7_50M    ... 0.44 0.56 0.52 0.43 0.49 0.56 0.64 0.78 77.97   0.98
# 9_338_300     ... 0.35 0.44 0.41 0.41 0.45 0.57 0.68 0.82 76.94   2.83
# 8_277_100     ... 0.35 0.50 0.55 0.57 0.63 0.72 0.87 1.04 77.35  -4.82
# 8_338_300     ... 0.41 0.52 0.57 0.61 0.63 0.72 0.85 1.03 77.85   2.08
# 318_4_5_50M   ... 0.36 0.51 0.54 0.55 0.62 0.71 0.77 0.90 75.00  -3.20
# 338_3_5_50M   ... 0.34 0.46 0.46 0.48 0.54 0.62 0.66 0.77 64.95   9.32
# 5_5_296_150   ... 0.33 0.47 0.45 0.47 0.50 0.57 0.69 0.87 80.36  -4.09
# 5_5_296_50    ... 0.41 0.56 0.57 0.54 0.60 0.71 0.80 0.96 79.71  -3.61
# 277K_7_250M   ... 0.30 0.48 0.44 0.51 0.60 0.72 0.85 1.01 77.93  -4.86
# 318_3_5_250M  ... 0.39 0.54 0.55 0.53 0.53 0.64 0.75 0.90 59.52   1.38
# 7_296_50      ... 0.34 0.43 0.48 0.50 0.51 0.60 0.71 0.87 77.97  -4.65
# 296_4_5_50M   ... 0.28 0.41 0.40 0.37 0.40 0.51 0.62 0.78 75.00  -4.12
# 4_5_338_50    ... 0.37 0.51 0.54 0.58 0.62 0.76 0.84 0.96 75.00   4.90
# 277K_7_150M   ... 0.31 0.42 0.48 0.50 0.58 0.76 0.93 1.14 78.63  -5.32
# 296_3_5_250M  ... 0.38 0.52 0.57 0.63 0.63 0.77 0.87 1.04 59.52  -3.81
# 4_5_338_100   ... 0.34 0.47 0.44 0.42 0.44 0.48 0.58 0.68 73.96   5.60
# 7_296_150     ... 0.35 0.52 0.52 0.54 0.59 0.75 0.91 1.09 78.63  -4.02
# 8_338_200     ... 0.34 0.44 0.46 0.45 0.53 0.60 0.67 0.78 77.94   2.18
# 4_5_338_150   ... 0.39 0.50 0.52 0.51 0.57 0.63 0.75 0.90 73.31   6.54
# 277_4_5_250M  ... 0.30 0.48 0.45 0.44 0.52 0.64 0.80 0.96 73.07  -3.59
#
# [49 rows x 453 columns]

# %%
# Select the columns as predictor variables (X)

X = rmsf_sasa_nc_agg.drop(['sum_aprsasa','Tm','ln(v)'],axis = 1)

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = rmsf_sasa_nc_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  24%|██████████▏                                | 10/42 [00:02<00:08,  3.77it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  50%|█████████████████████▌                     | 21/42 [00:04<00:06,  3.27it/s]
# LassoLarsIC model failed to execute
# You are using LassoLarsIC in the case where the number of samples is smaller than the number of features. In this setting, getting a good estimate for the variance of the noise is not possible. Provide an estimate of the noise variance in the constructor.
#  62%|██████████████████████████▌                | 26/42 [00:04<00:03,  5.31it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# RANSACRegressor model failed to execute
# `min_samples` may not be larger than number of samples: n_samples = 39.
# 100%|███████████████████████████████████████████| 42/42 [00:05<00:00,  7.62it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                             Adjusted R-Squared  \
# Model
# Lars                          12369063119915347190201974784.00
# OrthogonalMatchingPursuit                                 1.18
# QuantileRegressor                                         1.06
# HistGradientBoostingRegressor                             1.05
# DummyRegressor                                            1.05
# LGBMRegressor                                             1.05
# GaussianProcessRegressor                                  1.04
# OrthogonalMatchingPursuitCV                               1.02
# SGDRegressor                                              1.02
# XGBRegressor                                              1.02
# HuberRegressor                                            1.02
# LinearSVR                                                 1.02
# TransformedTargetRegressor                                1.02
# LinearRegression                                          1.02
# Ridge                                                     1.02
# PassiveAggressiveRegressor                                1.02
# MLPRegressor                                              1.02
# RidgeCV                                                   1.01
# KernelRidge                                               1.01
# TweedieRegressor                                          1.01
# LarsCV                                                    1.01
# ExtraTreesRegressor                                       1.01
# GradientBoostingRegressor                                 1.01
# KNeighborsRegressor                                       1.01
# BayesianRidge                                             1.01
# RandomForestRegressor                                     1.01
# LassoLars                                                 1.01
# Lasso                                                     1.01
# NuSVR                                                     1.01
# LassoLarsCV                                               1.01
# LassoCV                                                   1.01
# DecisionTreeRegressor                                     1.01
# ElasticNet                                                1.01
# ElasticNetCV                                              1.01
# ExtraTreeRegressor                                        1.01
# BaggingRegressor                                          1.00
# SVR                                                       1.00
# AdaBoostRegressor                                         1.00
#
#                                                        R-Squared  \
# Model
# Lars                          -606084092875852102479850242048.00
# OrthogonalMatchingPursuit                                  -8.05
# QuantileRegressor                                          -1.98
# HistGradientBoostingRegressor                              -1.46
# DummyRegressor                                             -1.46
# LGBMRegressor                                              -1.46
# GaussianProcessRegressor                                   -0.81
# OrthogonalMatchingPursuitCV                                -0.22
# SGDRegressor                                               -0.15
# XGBRegressor                                               -0.10
# HuberRegressor                                              0.13
# LinearSVR                                                   0.13
# TransformedTargetRegressor                                  0.13
# LinearRegression                                            0.13
# Ridge                                                       0.15
# PassiveAggressiveRegressor                                  0.19
# MLPRegressor                                                0.24
# RidgeCV                                                     0.27
# KernelRidge                                                 0.28
# TweedieRegressor                                            0.37
# LarsCV                                                      0.37
# ExtraTreesRegressor                                         0.42
# GradientBoostingRegressor                                   0.45
# KNeighborsRegressor                                         0.45
# BayesianRidge                                               0.45
# RandomForestRegressor                                       0.53
# LassoLars                                                   0.55
# Lasso                                                       0.55
# NuSVR                                                       0.55
# LassoLarsCV                                                 0.58
# LassoCV                                                     0.58
# DecisionTreeRegressor                                       0.58
# ElasticNet                                                  0.60
# ElasticNetCV                                                0.60
# ExtraTreeRegressor                                          0.74
# BaggingRegressor                                            0.76
# SVR                                                         0.79
# AdaBoostRegressor                                           0.92
#
#                                              RMSE  Time Taken
# Model
# Lars                          2113654736817712.75        0.09
# OrthogonalMatchingPursuit                    8.17        0.01
# QuantileRegressor                            4.69        0.03
# HistGradientBoostingRegressor                4.26        0.08
# DummyRegressor                               4.26        0.01
# LGBMRegressor                                4.26        0.02
# GaussianProcessRegressor                     3.65        0.01
# OrthogonalMatchingPursuitCV                  2.99        0.02
# SGDRegressor                                 2.91        0.01
# XGBRegressor                                 2.85        0.12
# HuberRegressor                               2.54        0.03
# LinearSVR                                    2.54        0.01
# TransformedTargetRegressor                   2.53        0.01
# LinearRegression                             2.53        0.01
# Ridge                                        2.50        0.01
# PassiveAggressiveRegressor                   2.44        0.01
# MLPRegressor                                 2.37        0.25
# RidgeCV                                      2.32        0.01
# KernelRidge                                  2.30        0.01
# TweedieRegressor                             2.15        0.01
# LarsCV                                       2.15        0.41
# ExtraTreesRegressor                          2.07        0.18
# GradientBoostingRegressor                    2.02        0.29
# KNeighborsRegressor                          2.02        0.01
# BayesianRidge                                2.01        0.04
# RandomForestRegressor                        1.86        0.32
# LassoLars                                    1.83        0.01
# Lasso                                        1.83        0.01
# NuSVR                                        1.82        0.01
# LassoLarsCV                                  1.77        0.04
# LassoCV                                      1.76        1.44
# DecisionTreeRegressor                        1.76        0.01
# ElasticNet                                   1.71        0.01
# ElasticNetCV                                 1.71        1.81
# ExtraTreeRegressor                           1.37        0.01
# BaggingRegressor                             1.32        0.04
# SVR                                          1.25        0.01
# AdaBoostRegressor                            0.77        0.10

# %% [markdown]
# #### sum SASA of 7 APRs, average native contacts of last 50ns, mean RMSF, one varaible Y lnv

# %%
# read the excel data of the mean rmsf and their aggregation rates

mean_rmsf = pd.read_excel("mean_rmsf_agg.xlsx",index_col=0)

# join the dataframes
mean_rmsf_nc_sasa_agg = pd.concat([nc,sasa_apr,mean_rmsf],axis=1,join='inner')

# save the dataframe to an excel file
#mean_rmsf_nc_sasa_agg.to_excel("mean_rmsf_nc_sasa_agg.xlsx")

# %%
mean_rmsf_nc_sasa_agg
# Out:
#               Average native contact (last 50ns)  r_31-36  r_47-51  r_114-118  \
# 3_5_277_0                                   0.21     0.37     0.02       0.25
# 8_338_0                                     0.23     0.71     0.57       0.32
# 3_5_338_100                                 0.23     0.61     0.44       0.87
# 3_5_338_200                                 0.26     1.13     0.58       0.48
# 5_5_296_250                                 0.21     0.28     0.09       0.08
# 9_338_200                                   0.21     1.05     0.47       0.25
# 318K_7_250M                                 0.23     0.73     0.45       0.29
# 3_5_277_50                                  0.21     0.37     0.24       0.10
# 296K_7_50M                                  0.20     0.15     0.08       0.11
# 4_5_296_250                                 0.22     0.66     0.29       0.44
# 318_4_5_150M                                0.43     0.21    -0.06      -0.10
# 7_296_250                                   0.18     0.62     0.38      -0.05
# 8_338_500                                   0.24     0.89     0.53       0.48
# 7_338_0                                     0.23     1.17     0.61       0.61
# 9_338_100                                   0.19     0.81     0.67       0.74
# 277_3_5_150M                                0.21     0.15     0.17       0.11
# 3_5_338_250                                 0.23     0.79     0.55       0.30
# 9_338_500                                   0.25     1.22     0.57       0.68
# 3_5_338_150                                 0.23     0.44     0.10       0.24
# 5_5_296_100                                 0.24     0.51    -0.00       0.31
# 4_5_338_0                                   0.24     0.80     0.39       0.17
# 4_5_338_200                                 0.24     1.00     0.54       0.94
# 9_338_400                                   0.22     0.61     0.35       0.53
# 338_4_5_250M                                0.46     0.28    -0.07      -0.23
# 9_338_0                                     0.25     0.38     0.22       0.19
# 5_5_296_0                                   0.20     0.66     0.15       0.05
# 8_338_400                                   0.26     1.18     0.81       0.08
# 277K_7_150M        0.14 78.63  -5.32
# 296_3_5_250M       0.15 59.52  -3.81
# 4_5_338_100        0.18 73.96   5.60
# 7_296_150          0.14 78.63  -4.02
# 8_338_200          0.18 77.94   2.18
# 4_5_338_150        0.18 73.31   6.54
# 277_4_5_250M       0.13 73.07  -3.59

# %%
# Select the columns as predictor variables (X)

X = mean_rmsf_nc_sasa_agg[['Average native contact (last 50ns)','sum_aprsasa','mean RMSF']]

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_nc_sasa_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  52%|██████████████████████                    | 22/42 [00:00<00:00, 106.96it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# 100%|██████████████████████████████████████████| 42/42 [00:00<00:00, 108.90it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreeRegressor                           0.67       0.78  1.28        0.00
# XGBRegressor                                 0.55       0.70  1.49        0.05
# SVR                                          0.48       0.66  1.59        0.00
# KernelRidge                                  0.46       0.64  1.63        0.00
# OrthogonalMatchingPursuitCV                  0.26       0.51  1.90        0.00
# OrthogonalMatchingPursuit                    0.26       0.51  1.90        0.00
# GradientBoostingRegressor                    0.17       0.45  2.02        0.02
# RandomForestRegressor                        0.15       0.44  2.04        0.04
# LassoLars                                    0.15       0.43  2.05        0.00
# Lasso                                        0.15       0.43  2.05        0.00
# AdaBoostRegressor                            0.13       0.42  2.07        0.04
# LinearSVR                                    0.11       0.40  2.10        0.00
# BaggingRegressor                             0.08       0.39  2.12        0.01
# LarsCV                                       0.07       0.38  2.13        0.00
# LassoLarsCV                                  0.07       0.38  2.13        0.00
# LassoLarsIC                                  0.07       0.38  2.13        0.00
# LassoCV                                      0.07       0.38  2.13        0.02
# Lars                                         0.07       0.38  2.14        0.00
# TransformedTargetRegressor                   0.07       0.38  2.14        0.00
# LinearRegression                             0.07       0.38  2.14        0.00
# ExtraTreesRegressor                          0.06       0.38  2.14        0.03
# HuberRegressor                               0.06       0.37  2.15        0.00
# RidgeCV                                      0.06       0.37  2.15        0.00
# Ridge                                        0.06       0.37  2.15        0.00
# ElasticNetCV                                 0.05       0.37  2.16        0.02
# DecisionTreeRegressor                        0.05       0.37  2.16        0.00
# KNeighborsRegressor                          0.05       0.36  2.16        0.00
# BayesianRidge                                0.04       0.36  2.17        0.00
# SGDRegressor                                 0.00       0.34  2.21        0.00
# MLPRegressor                                -0.11       0.26  2.34        0.02
# NuSVR                                       -0.11       0.26  2.34        0.00
# PassiveAggressiveRegressor                  -0.36       0.09  2.58        0.00
# ElasticNet                                  -0.36       0.09  2.59        0.00
# TweedieRegressor                            -0.53      -0.02  2.74        0.00
# RANSACRegressor                             -0.97      -0.31  3.11        0.00
# LGBMRegressor                               -2.69      -1.46  4.26        0.01
# DummyRegressor                              -2.69      -1.46  4.26        0.00
# HistGradientBoostingRegressor               -2.69      -1.46  4.26        0.04
# QuantileRegressor                           -3.47      -1.98  4.69        0.01
# GaussianProcessRegressor                    -9.58      -6.05  7.21        0.00

# %% [markdown]
# #### 7 APRs, sum of APR, native contacts, mean RMSF

# %%
# read the excel data of the mean rmsf and their aggregation rates

mean_rmsf_nc_sasa_agg = pd.read_excel("mean_rmsf_nc_sasa_agg.xlsx",index_col=0)

# Select the columns as predictor variables (X)

X = mean_rmsf_nc_sasa_agg.drop(['Tm','ln(v)'],axis = 1)

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_nc_sasa_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  48%|████████████████████▍                      | 20/42 [00:00<00:00, 88.90it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 99.20it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# QuantileRegressor                           27.81      -1.98  4.69        0.01
# DummyRegressor                              23.16      -1.46  4.26        0.00
# HistGradientBoostingRegressor               23.16      -1.46  4.26        0.04
# LGBMRegressor                               23.16      -1.46  4.26        0.01
# MLPRegressor                                14.03      -0.45  3.27        0.02
# TweedieRegressor                            13.31      -0.37  3.18        0.00
# ExtraTreeRegressor                          12.48      -0.28  3.07        0.00
# PassiveAggressiveRegressor                  11.84      -0.20  2.98        0.00
# ElasticNet                                  11.47      -0.16  2.93        0.00
# NuSVR                                       11.05      -0.12  2.87        0.00
# RANSACRegressor                             10.81      -0.09  2.83        0.01
# KNeighborsRegressor                         10.75      -0.08  2.83        0.00
# RidgeCV                                     10.38      -0.04  2.77        0.00
# GaussianProcessRegressor                    10.04      -0.00  2.72        0.00
# TransformedTargetRegressor                   9.77       0.03  2.68        0.00
# LinearRegression                             9.77       0.03  2.68        0.00
# Lars                                         9.77       0.03  2.68        0.00
# BayesianRidge                                9.71       0.03  2.67        0.00
# Ridge                                        9.55       0.05  2.65        0.00
# SVR                                          9.51       0.05  2.64        0.00
# SGDRegressor                                 9.38       0.07  2.62        0.00
# HuberRegressor                               8.62       0.15  2.50        0.00
# ExtraTreesRegressor                          8.56       0.16  2.49        0.03
# ElasticNetCV                                 8.22       0.20  2.43        0.02
# RandomForestRegressor                        7.95       0.23  2.39        0.05
# GradientBoostingRegressor                    7.77       0.25  2.35        0.02
# KernelRidge                                  7.39       0.29  2.29        0.00
# DecisionTreeRegressor                        7.27       0.30  2.27        0.00
# BaggingRegressor                             7.21       0.31  2.26        0.01
# XGBRegressor                                 7.07       0.33  2.23        0.05
# LinearSVR                                    6.98       0.34  2.21        0.00
# LassoLars                                    6.24       0.42  2.07        0.00
# Lasso                                        6.24       0.42  2.07        0.00
# LassoLarsIC                                  6.15       0.43  2.05        0.00
# LassoLarsCV                                  6.08       0.44  2.04        0.01
# LassoCV                                      6.08       0.44  2.04        0.02
# LarsCV                                       6.06       0.44  2.04        0.01
# OrthogonalMatchingPursuitCV                  5.42       0.51  1.90        0.00
# OrthogonalMatchingPursuit                    5.42       0.51  1.90        0.00
# AdaBoostRegressor                            4.77       0.58  1.76        0.04

# %% [markdown]
# # Native contacts, total SASA, non-polar SASA, APR SASA vs lnv

# %% [markdown]
# ### Updated version 061123 nc

# %%
import pandas as pd

# Read mean_rmsf_nc_sasa_agg

mean_rmsf_nc_sasa_agg = pd.read_excel("mean_rmsf_nc_sasa_agg061123.xlsx",index_col=0)

# read total SASA, non-polar SASA

total_sasa = pd.read_excel("SASA281023.xlsx", index_col=0)

# join the dataframes
mean_rmsf_nc_sasa_agg_total_sasa = pd.concat([total_sasa,mean_rmsf_nc_sasa_agg],axis=1,join='inner')

# save the dataframe into an excel file
#mean_rmsf_nc_sasa_agg_total_sasa.to_excel("mean_rmsf_nc_sasa_agg_total_sasa061123.xlsx")

# %% [markdown]
# ####  total SASA, Non-polar SASA, native contacts, 7 APR SASAs, lnv as Y

# %%
# Select the columns as predictor variables (X)

X = mean_rmsf_nc_sasa_agg_total_sasa.drop(['Tm','ln(v)','mean RMSF','sum_aprsasa'],axis = 1)

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_nc_sasa_agg_total_sasa['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  31%|███       | 13/42 [00:00<00:00, 33.20it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  83%|████████▎ | 35/42 [00:00<00:00, 49.28it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# 100%|██████████| 42/42 [00:00<00:00, 42.34it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# Lars                                       163.16     -17.02 11.52        0.01
# RANSACRegressor                             37.30      -3.03  5.45        0.02
# SGDRegressor                                30.14      -2.24  4.89        0.07
# Ridge                                       30.06      -2.23  4.88        0.01
# QuantileRegressor                           27.81      -1.98  4.69        0.02
# RidgeCV                                     26.33      -1.81  4.55        0.01
# MLPRegressor                                26.03      -1.78  4.53        0.04
# HuberRegressor                              25.86      -1.76  4.51        0.01
# KernelRidge                                 23.77      -1.53  4.32        0.01
# Lasso                                       23.21      -1.47  4.27        0.01
# LassoLars                                   23.21      -1.47  4.27        0.01
# HistGradientBoostingRegressor               23.16      -1.46  4.26        0.08
# DummyRegressor                              23.16      -1.46  4.26        0.00
# LGBMRegressor                               23.16      -1.46  4.26        0.01
# ElasticNetCV                                22.94      -1.44  4.24        0.06
# LinearRegression                            22.89      -1.43  4.23        0.00
# TransformedTargetRegressor                  22.89      -1.43  4.23        0.01
# BayesianRidge                               22.73      -1.41  4.22        0.01
# LassoLarsIC                                 22.50      -1.39  4.20        0.01
# ElasticNet                                  22.40      -1.38  4.19        0.01
# LassoCV                                     22.39      -1.38  4.19        0.10
# LarsCV                                      22.39      -1.38  4.19        0.01
# LassoLarsCV                                 22.30      -1.37  4.18        0.01
# TweedieRegressor                            21.53      -1.28  4.10        0.01
# KNeighborsRegressor                         21.48      -1.28  4.10        0.01
# LinearSVR                                   19.76      -1.08  3.92        0.01
# PassiveAggressiveRegressor                  18.88      -0.99  3.83        0.01
# OrthogonalMatchingPursuit                   16.32      -0.70  3.54        0.01
# OrthogonalMatchingPursuitCV                 16.32      -0.70  3.54        0.01
# GaussianProcessRegressor                    15.88      -0.65  3.49        0.01
# SVR                                         14.61      -0.51  3.34        0.01
# NuSVR                                       14.00      -0.44  3.26        0.01
# ExtraTreesRegressor                         11.43      -0.16  2.92        0.06
# ExtraTreeRegressor                          11.36      -0.15  2.91        0.01
# BaggingRegressor                            11.09      -0.12  2.87        0.02
# RandomForestRegressor                       10.25      -0.03  2.75        0.08
# GradientBoostingRegressor                    9.67       0.04  2.67        0.04
# AdaBoostRegressor                            7.72       0.25  2.35        0.11
# XGBRegressor                                 5.25       0.53  1.87        0.09
# DecisionTreeRegressor                        4.99       0.56  1.81        0.01

# %% [markdown]
# ####  total SASA, non-polar SASA, native contacts, sum of APR SASA, 7 APR SASAs, mean RMSF, lnv as Y

# %%
# Select the columns as predictor variables (X)

X = mean_rmsf_nc_sasa_agg_total_sasa.drop(['Tm','ln(v)'],axis = 1)

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_nc_sasa_agg_total_sasa['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  31%|█████████████▎                             | 13/42 [00:00<00:00, 42.26it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  90%|██████████████████████████████████████▉    | 38/42 [00:00<00:00, 63.58it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 57.19it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# QuantileRegressor                            9.94      -1.98  4.69        0.02
# PassiveAggressiveRegressor                   8.56      -1.52  4.31        0.01
# DummyRegressor                               8.39      -1.46  4.26        0.00
# HistGradientBoostingRegressor                8.39      -1.46  4.26        0.06
# LGBMRegressor                                8.39      -1.46  4.26        0.01
# Lars                                         7.07      -1.02  3.86        0.01
# HuberRegressor                               6.68      -0.89  3.74        0.01
# RANSACRegressor                              5.92      -0.64  3.48        0.02
# TransformedTargetRegressor                   5.81      -0.60  3.44        0.01
# LinearRegression                             5.81      -0.60  3.44        0.01
# TweedieRegressor                             5.16      -0.39  3.20        0.01
# XGBRegressor                                 4.80      -0.27  3.06        0.07
# ExtraTreeRegressor                           4.72      -0.24  3.02        0.01
# MLPRegressor                                 4.65      -0.22  3.00        0.04
# Ridge                                        4.56      -0.19  2.96        0.00
# ElasticNet                                   4.43      -0.14  2.90        0.01
# KNeighborsRegressor                          4.41      -0.14  2.89        0.00
# NuSVR                                        4.35      -0.12  2.87        0.01
# RidgeCV                                      4.24      -0.08  2.82        0.00
# LinearSVR                                    4.15      -0.05  2.78        0.01
# SGDRegressor                                 4.15      -0.05  2.78        0.01
# BayesianRidge                                4.11      -0.04  2.77        0.01
# GaussianProcessRegressor                     4.03      -0.01  2.73        0.01
# BaggingRegressor                             3.85       0.05  2.64        0.02
# KernelRidge                                  3.83       0.06  2.64        0.00
# SVR                                          3.62       0.13  2.54        0.00
# AdaBoostRegressor                            3.60       0.13  2.53        0.05
# ElasticNetCV                                 3.45       0.18  2.45        0.05
# GradientBoostingRegressor                    3.33       0.22  2.39        0.04
# RandomForestRegressor                        3.32       0.23  2.39        0.08
# ExtraTreesRegressor                          3.00       0.33  2.22        0.05
# Lasso                                        2.75       0.42  2.07        0.00
# LassoLars                                    2.75       0.42  2.07        0.01
# DecisionTreeRegressor                        2.73       0.42  2.06        0.01
# LassoLarsIC                                  2.72       0.43  2.05        0.01
# LassoLarsCV                                  2.69       0.44  2.04        0.01
# LassoCV                                      2.69       0.44  2.04        0.06
# LarsCV                                       2.69       0.44  2.04        0.01
# OrthogonalMatchingPursuitCV                  2.47       0.51  1.90        0.01
# OrthogonalMatchingPursuit                    2.47       0.51  1.90        0.00

# %% [markdown]
# #### total SASA, non-polar SASA, native contacts, sum of APR SASA, mean RMSF, lnv as Y

# %%
import pandas as pd

# Read mean_rmsf_nc_sasa_agg_total_sasa

mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa061123.xlsx",index_col=0)

# Select the columns as predictor variables (X)

X = mean_rmsf_nc_sasa_agg_total_sasa[['Non_polar SASA', 'Total SASA','Average native contact (last 50ns)','sum_aprsasa','mean RMSF']]

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_nc_sasa_agg_total_sasa['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  60%|█████████████████████████▌                 | 25/42 [00:00<00:00, 72.51it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 66.01it/s]
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# DecisionTreeRegressor                        0.19       0.64  1.63        0.00
# KernelRidge                                  0.10       0.60  1.72        0.00
# SVR                                          0.09       0.59  1.73        0.00
# OrthogonalMatchingPursuitCV                 -0.10       0.51  1.90        0.01
# OrthogonalMatchingPursuit                   -0.10       0.51  1.90        0.01
# XGBRegressor                                -0.17       0.48  1.96        0.07
# MLPRegressor                                -0.28       0.43  2.05        0.04
# LassoLars                                   -0.28       0.43  2.05        0.00
# Lasso                                       -0.28       0.43  2.05        0.00
# SGDRegressor                                -0.34       0.40  2.10        0.00
# LinearSVR                                   -0.36       0.40  2.11        0.00
# LassoCV                                     -0.37       0.39  2.12        0.05
# LarsCV                                      -0.37       0.39  2.12        0.01
# LassoLarsCV                                 -0.37       0.39  2.12        0.01
# LassoLarsIC                                 -0.40       0.38  2.14        0.01
# ElasticNetCV                                -0.45       0.35  2.18        0.04
# BayesianRidge                               -0.45       0.35  2.18        0.00
# ExtraTreesRegressor                         -0.46       0.35  2.19        0.05
# RidgeCV                                     -0.50       0.33  2.22        0.00
# Ridge                                       -0.50       0.33  2.22        0.00
# RandomForestRegressor                       -0.50       0.33  2.22        0.07
# BaggingRegressor                            -0.64       0.27  2.32        0.01
# NuSVR                                       -0.77       0.21  2.41        0.01
# KNeighborsRegressor                         -0.87       0.17  2.47        0.00
# AdaBoostRegressor                           -0.92       0.15  2.51        0.04
# Lars                                        -0.93       0.14  2.51        0.00
# LinearRegression                            -0.93       0.14  2.51        0.00
# TransformedTargetRegressor                  -0.93       0.14  2.51        0.00
# GradientBoostingRegressor                   -1.00       0.11  2.56        0.03
# HuberRegressor                              -1.03       0.10  2.58        0.01
# ElasticNet                                  -1.06       0.09  2.60        0.00
# TweedieRegressor                            -1.40      -0.07  2.81        0.01
# RANSACRegressor                             -1.74      -0.22  2.99        0.01
# PassiveAggressiveRegressor                  -3.09      -0.82  3.66        0.00
# ExtraTreeRegressor                          -3.49      -1.00  3.84        0.01
# GaussianProcessRegressor                    -3.50      -1.00  3.84        0.01
# LGBMRegressor                               -4.54      -1.46  4.26        0.01
# HistGradientBoostingRegressor               -4.54      -1.46  4.26        0.05
# DummyRegressor                              -4.54      -1.46  4.26        0.00
# QuantileRegressor                           -5.70      -1.98  4.69        0.01

# %% [markdown]
# ### Older version, nc - salt bridges fraction

# %% [markdown]
# ##### Read the files

# %%
import pandas as pd

# Read mean_rmsf_nc_sasa_agg

mean_rmsf_nc_sasa_agg = pd.read_excel("mean_rmsf_nc_sasa_agg.xlsx",index_col=0)

# read total SASA, non-polar SASA

total_sasa = pd.read_excel("SASA281023.xlsx", index_col=0)

# join the dataframes
mean_rmsf_nc_sasa_agg_total_sasa = pd.concat([total_sasa,mean_rmsf_nc_sasa_agg],axis=1,join='inner')

# save the dataframe into an excel file
#mean_rmsf_nc_sasa_agg_total_sasa.to_excel("mean_rmsf_nc_sasa_agg_total_sasa.xlsx")

# %% [markdown]
# #### total SASA, non-polar SASA, native contacts, sum of APR SASA, 7 APR SASAs, mean RMSF, lnv as Y

# %%
# Select the columns as predictor variables (X)

X = mean_rmsf_nc_sasa_agg_total_sasa.drop(['Tm','ln(v)'],axis = 1)

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_nc_sasa_agg_total_sasa['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  48%|████████████████████▍                      | 20/42 [00:00<00:00, 85.65it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 95.97it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# Lars                                        31.12      -9.04  8.60        0.00
# QuantileRegressor                            9.94      -1.98  4.69        0.01
# DummyRegressor                               8.39      -1.46  4.26        0.00
# HistGradientBoostingRegressor                8.39      -1.46  4.26        0.04
# LGBMRegressor                                8.39      -1.46  4.26        0.01
# ExtraTreeRegressor                           6.82      -0.94  3.78        0.00
# PassiveAggressiveRegressor                   6.24      -0.75  3.59        0.00
# TransformedTargetRegressor                   5.50      -0.50  3.32        0.00
# LinearRegression                             5.50      -0.50  3.32        0.00
# RANSACRegressor                              5.23      -0.41  3.23        0.01
# DecisionTreeRegressor                        5.20      -0.40  3.21        0.00
# TweedieRegressor                             5.03      -0.34  3.15        0.00
# MLPRegressor                                 4.76      -0.25  3.04        0.02
# HuberRegressor                               4.53      -0.18  2.94        0.01
# ElasticNet                                   4.43      -0.14  2.90        0.00
# KNeighborsRegressor                          4.41      -0.14  2.89        0.00
# NuSVR                                        4.34      -0.11  2.87        0.00
# Ridge                                        4.16      -0.05  2.78        0.00
# RidgeCV                                      4.08      -0.03  2.75        0.00
# GaussianProcessRegressor                     4.04      -0.01  2.74        0.00
# BayesianRidge                                3.91       0.03  2.67        0.00
# SGDRegressor                                 3.86       0.05  2.65        0.00
# SVR                                          3.68       0.11  2.57        0.00
# BaggingRegressor                             3.57       0.14  2.51        0.01
# XGBRegressor                                 3.47       0.18  2.46        0.04
# ElasticNetCV                                 3.41       0.20  2.43        0.02
# KernelRidge                                  3.40       0.20  2.43        0.00
# GradientBoostingRegressor                    3.37       0.21  2.41        0.02
# ExtraTreesRegressor                          3.34       0.22  2.40        0.03
# RandomForestRegressor                        3.29       0.24  2.37        0.05
# LinearSVR                                    3.02       0.33  2.23        0.00
# AdaBoostRegressor                            2.91       0.36  2.17        0.03
# Lasso                                        2.75       0.42  2.07        0.00
# LassoLars                                    2.75       0.42  2.07        0.00
# LarsCV                                       2.74       0.42  2.07        0.01
# LassoLarsIC                                  2.72       0.43  2.05        0.00
# LassoLarsCV                                  2.69       0.44  2.04        0.01
# LassoCV                                      2.69       0.44  2.04        0.03
# OrthogonalMatchingPursuitCV                  2.47       0.51  1.90        0.00
# OrthogonalMatchingPursuit                    2.47       0.51  1.90        0.00

# %% [markdown]
# #### total SASA, non-polar SASA, native contacts, sum of APR SASA, mean RMSF, lnv as Y

# %%
import pandas as pd

# Read mean_rmsf_nc_sasa_agg_total_sasa

mean_rmsf_nc_sasa_agg = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa.xlsx",index_col=0)

# Select the columns as predictor variables (X)

X = mean_rmsf_nc_sasa_agg[['Non_polar SASA', 'Total SASA','Average native contact (last 50ns)','sum_aprsasa','mean RMSF']]

# convert X columns to strings

X.columns = X.columns.astype(str)

# 'ln(v)' is the target Y variable

Y = mean_rmsf_nc_sasa_agg['ln(v)']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 64)
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#  48%|████████████████████▍                      | 20/42 [00:00<00:00, 96.53it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# PoissonRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# 100%|██████████████████████████████████████████| 42/42 [00:00<00:00, 108.58it/s]
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 39, number of used features: 0
# [LightGBM] [Info] Start training from score 0.841535
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# KernelRidge                                  0.16       0.63  1.66        0.00
# SVR                                          0.03       0.57  1.78        0.00
# OrthogonalMatchingPursuitCV                 -0.10       0.51  1.90        0.00
# OrthogonalMatchingPursuit                   -0.10       0.51  1.90        0.00
# XGBRegressor                                -0.16       0.49  1.95        0.05
# LinearSVR                                   -0.23       0.45  2.01        0.00
# AdaBoostRegressor                           -0.25       0.44  2.03        0.04
# MLPRegressor                                -0.28       0.43  2.04        0.02
# LassoLars                                   -0.28       0.43  2.05        0.00
# Lasso                                       -0.28       0.43  2.05        0.00
# RandomForestRegressor                       -0.31       0.42  2.07        0.04
# ExtraTreesRegressor                         -0.33       0.41  2.09        0.03
# LarsCV                                      -0.35       0.40  2.10        0.00
# LassoLarsCV                                 -0.35       0.40  2.10        0.01
# LassoCV                                     -0.35       0.40  2.10        0.02
# SGDRegressor                                -0.38       0.38  2.13        0.00
# LassoLarsIC                                 -0.39       0.38  2.13        0.00
# Lars                                        -0.40       0.38  2.14        0.00
# ElasticNetCV                                -0.43       0.36  2.17        0.02
# BayesianRidge                               -0.44       0.36  2.17        0.00
# Ridge                                       -0.45       0.36  2.18        0.00
# GaussianProcessRegressor                    -0.61       0.28  2.30        0.00
# RidgeCV                                     -0.67       0.26  2.34        0.00
# LinearRegression                            -0.67       0.26  2.34        0.00
# TransformedTargetRegressor                  -0.67       0.26  2.34        0.00
# GradientBoostingRegressor                   -0.78       0.21  2.41        0.02
# HuberRegressor                              -0.80       0.20  2.43        0.00
# BaggingRegressor                            -0.81       0.19  2.44        0.01
# NuSVR                                       -0.85       0.18  2.46        0.00
# KNeighborsRegressor                         -1.02       0.10  2.57        0.00
# ElasticNet                                  -1.06       0.09  2.60        0.00
# TweedieRegressor                            -1.35      -0.05  2.78        0.00
# RANSACRegressor                             -1.47      -0.10  2.84        0.00
# PassiveAggressiveRegressor                  -1.83      -0.26  3.04        0.00
# DecisionTreeRegressor                       -3.76      -1.12  3.95        0.00
# LGBMRegressor                               -4.54      -1.46  4.26        0.01
# DummyRegressor                              -4.54      -1.46  4.26        0.00
# HistGradientBoostingRegressor               -4.54      -1.46  4.26        0.04
# ExtraTreeRegressor                          -4.97      -1.66  4.42        0.00
# QuantileRegressor                           -5.70      -1.98  4.69        0.01

# %% [markdown]
# # Add number of Hbonds in the last 50ns

# %% [markdown]
# ### Updated version 061123

# %%
import pandas as pd

# Read mean_rmsf_nc_sasa_agg_total_sasa_temp061123
## note, this file was generated in section 6 since this section was added after section 6

mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp061123.xlsx",index_col=0)

# read Hbonds

hbond = pd.read_excel("AvgHbondsNumberLast50ns.xlsx", index_col=0)

# join the dataframes
mean_rmsf_nc_sasa_agg_total_sasa_hbond = pd.concat([hbond,mean_rmsf_nc_sasa_agg_total_sasa],axis=1,join='inner')

# save the dataframe into an excel file
#mean_rmsf_nc_sasa_agg_total_sasa_hbond.to_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond061123.xlsx")

# %%
hbond
# Out:
#          Condition  Number of hydrogen bonds in the last 50ns
# 0        3_5_277_0                                 299.118000
# 1          8_338_0                                 302.783667
# 2      3_5_338_100                                 301.456667
# 3      3_5_338_200                                 298.362333
# 4      5_5_296_250                                 301.627667
# 5        9_338_200                                 301.846667
# 6      318K_7_250M                                 302.444667
# 7       3_5_277_50                                 301.537333
# 8       296K_7_50M                                 302.171333
# 9      4_5_296_250                                 298.405000
# 10    318_4_5_150M                                 291.190083
# 11       7_296_250                                 302.785667
# 12       8_338_500                                 303.143333
# 13         7_338_0                                 302.633000
# 14       9_338_100                                 302.575333
# 15    277_3_5_150M                                 305.153667
# 16     3_5_338_250                                 303.062000
# 17       9_338_500                                 302.578667
# 18     3_5_338_150                                 298.643000
# 19     5_5_296_100                                 302.276333
# 20       4_5_338_0                                 298.708667
# 21     4_5_338_200                                 298.790667
# 22       9_338_400                                 299.003000
# 23  318_4_5_150M_2                                 291.293000
# 24    338_4_5_250M                                 288.767667
# 25         9_338_0                                 303.786333
# 26       5_5_296_0                                 300.230000
# 27       8_338_400                                 300.363667
# 28  338_4_5_250M_2                                 288.763667
# 29     5_5_296_200                                 299.965333
# 30     318K_7_150M                                 298.846000
# 31      338K_7_50M                                 296.035333
# 32       9_338_300                                 299.506667
# 33       8_277_100                                 296.767333
# 34       8_338_300                                 296.058000
# 35     318_4_5_50M                                 293.987667
# 36     338_3_5_50M                                 299.123000
# 37     5_5_296_150                                 298.377333
# 38  318_4_5_150M_3                                 289.848000
# 39      5_5_296_50                                 300.293667
# 40     277K_7_250M                                 298.963667
# 41    318_3_5_250M                                 302.378000
# 42        7_296_50                                 301.660667
# 43     296_4_5_50M                                 292.332167
# 44      4_5_338_50                                 296.695667
# 45   296_4_5_50M_2                                 293.478333
# 46     277K_7_150M                                 299.323333
# 47    296_3_5_250M                                 301.534000
# 48     4_5_338_100                                 302.746000
# 49       7_296_150                                 300.722000
# 50  318_4_5_150M_4                                 293.087333
# 51       8_338_200                                 301.222000
# 52     4_5_338_150                                 299.726667
# 53    277_4_5_250M                                 292.647667

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


df = mean_rmsf_nc_sasa_agg_total_sasa_hbond

# Set column 'Number' as the index
df.set_index('Number', inplace=True)

df = df.drop(['Condition'],axis = 1)

# To find the correlation among
# the columns using pearson method
df_correlation = df.corr(method ='pearson')

# save the pearson correlation to an excel
#df_correlation.to_excel("PearsonCorrelationMatrixPandas071123.xlsx")


# plot a heatmap
sns.heatmap(df_correlation, annot=True, annot_kws={"fontsize":5}, fmt=".2f",linewidth=.5, vmin = -1, vmax = 1)
# Out:
# <Axes: >

# %% [markdown]
# ### Old version, nc - salt bridge fraction

# %% [markdown]
# ###### Read the files

# %%
import pandas as pd

# Read mean_rmsf_nc_sasa_agg_total_sasa_temp311023.
## note, this file was generated in section 6 since this section was added after section 6

mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp311023.xlsx",index_col=1)

# drop the first column
mean_rmsf_nc_sasa_agg_total_sasa = mean_rmsf_nc_sasa_agg_total_sasa.drop(mean_rmsf_nc_sasa_agg_total_sasa.columns[0],axis=1)


# read Hbonds

hbond = pd.read_excel("AvgHbondsNumberLast50ns.xlsx", index_col=1)

# drop the first column
hbond = hbond.drop(hbond.columns[0],axis=1)

# join the dataframes
mean_rmsf_nc_sasa_agg_total_sasa_hbond = pd.concat([hbond,mean_rmsf_nc_sasa_agg_total_sasa],axis=1,join='inner')


# save the dataframe into an excel file
#mean_rmsf_nc_sasa_agg_total_sasa_hbond.to_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx")

# %%
mean_rmsf_nc_sasa_agg_total_sasa_hbond
# Out:
#               Number of hydrogen bonds in the last 50ns  Non_polar SASA  \
# Condition
# 3_5_277_0                                    299.118000      228.906489
# 8_338_0                                      302.783667      243.092681
# 3_5_338_100                                  301.456667      248.056974
# 3_5_338_200                                  298.362333      254.137026
# 5_5_296_250                                  301.627667      233.396841
# 9_338_200                                    301.846667      248.530223
# 318K_7_250M                                  302.444667      241.492613
# 3_5_277_50                                   301.537333      225.952698
# 296K_7_50M                                   302.171333      227.558598
# 4_5_296_250                                  298.405000      241.771463
# 318_4_5_150M                                 291.190083      220.925775
# 7_296_250                                    302.785667      229.587025
# 8_338_500                                    303.143333      242.604036
# 7_338_0                                      302.633000      255.936661
# 9_338_100                                    302.575333      255.132108
# 277_3_5_150M                                 305.153667      227.936189
# 3_5_338_250                                  303.062000      249.128889
# 9_338_500                                    302.578667      258.709485
# 3_5_338_150                                  298.643000      244.763815
# 5_5_296_100                                  302.276333      230.822841
# 4_5_338_0                                    298.708667      246.369025
# 4_5_338_200                                  298.790667      261.316079
# 9_338_400                                    299.003000      245.704627
# 338_4_5_250M                                 288.767667      220.415104
# 9_338_0                                      303.786333      243.874561
# 5_5_296_0                                    300.230000      225.926228
# 8_338_400                                    300.363667      239.585396
# 5_5_296_200                                  299.965333      227.709051
# 318K_7_150M                                  298.846000      237.414389
# 338K_7_50M                                   296.035333      260.943038
# 9_338_300                                    299.506667      244.707937
# 8_277_100                                    296.767333      229.544890
# 8_338_300                                    296.058000      248.165596
# 318_4_5_50M                                  293.987667      219.985909
# 338_3_5_50M                                  299.123000      238.543537
# 5_5_296_150                                  298.377333      232.199250
# 5_5_296_50                                   300.293667      237.490492
# 277K_7_250M                                  298.963667      233.393250
# 318_3_5_250M                                 302.378000      238.941337
# 7_296_50                                     301.660667      237.154328
# 296_4_5_50M                                  292.332167      219.378909
# 4_5_338_50                                   296.695667      257.612662
# 277K_7_150M                                  299.323333      236.798943
# 296_3_5_250M                                 301.534000      230.760015
# 4_5_338_100                                  302.746000      246.017968
# 7_296_150                                    300.722000      245.048021
# 8_338_200                                    301.222000      240.300576
# 4_5_338_150                                  299.726667      276.757861
# 277_4_5_250M                                 292.647667      221.585852
#
#               Total SASA  Average native contact (last 50ns)   r_31-36  \
# Condition
# 3_5_277_0     289.970744                            0.213763  0.372220
# 8_338_0       304.607920                            0.232773  0.705146
# 3_5_338_100   310.778369                            0.226088  0.613732
# 3_5_338_200   316.393640                            0.255331  1.129000
# 7_296_50         2.616084   0.141350  77.966067 -4.651002      40   296   50
# 296_4_5_50M      0.520811   0.131894  74.995800 -4.123900      41   296   50
# 4_5_338_50       5.278255   0.183102  74.995800  4.900827      42   338   50
# 277K_7_150M      3.522407   0.140163  78.629800 -5.324000      43   277  150
# 296_3_5_250M     1.143647   0.147359  59.523900 -3.813900      44   296  250
# 4_5_338_100      3.948199   0.179242  73.955500  5.599474      45   338  100
# 7_296_150        3.381823   0.143561  78.629833 -4.024684      46   296  150
# 8_338_200        3.443828   0.177470  77.940967  2.182835      47   338  200
# 4_5_338_150      8.947124   0.178461  73.311600  6.544445      48   338  150
# 277_4_5_250M    -0.113861   0.130951  73.072700 -3.586700      49   277  250
#
#                pH
# Condition
# 3_5_277_0     7.0
# 8_338_0       8.0
# 3_5_338_100   8.0
# 3_5_338_200   8.0
# 5_5_296_250   5.5
# 9_338_200     8.0
# 318K_7_250M   7.0
# 3_5_277_50    7.0
# 296K_7_50M    7.0
# 4_5_296_250   4.5
# 318_4_5_150M  8.0
# 7_296_250     7.0
# 8_338_500     8.0
# 7_338_0       7.0
# 9_338_100     8.0
# 277_3_5_150M  7.0
# 3_5_338_250   8.0
# 9_338_500     8.0
# 3_5_338_150   8.0
# 5_5_296_100   5.5
# 4_5_338_0     8.0
# 4_5_338_200   8.0
# 9_338_400     8.0
# 338_4_5_250M  8.0
# 9_338_0       8.0
# 5_5_296_0     5.5
# 8_338_400     8.0
# 5_5_296_200   5.5
# 318K_7_150M   7.0
# 338K_7_50M    7.0
# 9_338_300     8.0
# 8_277_100     7.0
# 8_338_300     8.0
# 318_4_5_50M   8.0
# 338_3_5_50M   8.0
# 5_5_296_150   5.5
# 5_5_296_50    5.5
# 277K_7_250M   7.0
# 318_3_5_250M  8.0
# 7_296_50      7.0
# 296_4_5_50M   4.5
# 4_5_338_50    8.0
# 277K_7_150M   7.0
# 296_3_5_250M  3.5
# 4_5_338_100   8.0
# 7_296_150     7.0
# 8_338_200     8.0
# 4_5_338_150   8.0
# 277_4_5_250M  7.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


df = mean_rmsf_nc_sasa_agg_total_sasa_hbond

# Set column 'Number' as the index
df.set_index('Number', inplace=True)

# if the column has a condition, delete it
try:
    df = df.drop(['Condition'],axis = 1)
    
except Exception:
    pass


# To find the correlation among
# the columns using pearson method
df_correlation = df.corr(method ='pearson')

# save the pearson correlation to an excel
#df_correlation.to_excel("PearsonCorrelationMatrixPandas011123.xlsx")


# plot a heatmap
sns.heatmap(df_correlation, annot=True, annot_kws={"fontsize":5}, fmt=".2f",linewidth=.5, vmin = -1, vmax = 1)
# Out:
# <Axes: >

# %% [markdown]
# # Analysis copying idea from papers - updated 061123

# %% [markdown]
# ### Paper: Machine Learning Applied to Determine the Molecular Descriptors Responsible for the Viscosity Behavior of Concentrated Therapeutic Antibodies - Ping-kuang Lai, Bernard Trout
#
# Paper:
#
# https://pubs.acs.org/doi/full/10.1021/acs.molpharmaceut.0c01073

# %%
import pandas as pd

# Read the dataframe 

mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa061123.xlsx")

# Give name to the first column
mean_rmsf_nc_sasa_agg_total_sasa.columns.values[0] = 'Condition'

# Add a new column 'RowNumber' with row count starting from 1
mean_rmsf_nc_sasa_agg_total_sasa['Number'] = mean_rmsf_nc_sasa_agg_total_sasa.reset_index().index + 1

# Save the dataframe to an excel 
#mean_rmsf_nc_sasa_agg_total_sasa.to_excel("mean_rmsf_nc_sasa_agg_total_sasa_number061123.xlsx")

# %% [markdown]
# #### A bar chart of the aggregation rates of the 49 conditions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_number061123.xlsx",index_col=0)

# Set the size of the plot
plt.figure(figsize=(12, 8))

sns.barplot(mean_rmsf_nc_sasa_agg_total_sasa, x="Number", y="ln(v)")

# Show the plot
plt.show()

# %% [markdown]
# #### A scatter plot of sum_aprsasa vs ln(v)

# %% [markdown]
# ###### Add temp, IS, pH columns into the dataframe

# %%
i = '_0'
a = int(i.strip("_"))
a
# Out:
# 0

# %%
# define a function to assign temp, IS, pH columns into a pandas dataframe

## update 19/11/23
## r'^7_|_7_' the ^ is needed otherwise it will get the 7 in 277 


import pandas as pd
import re

def assign_conditions(df):
    temp_values = ['277', '296', '318', '338']
    IS_values = ['_0', '50', '100', '150', '200', '250', '300', '400', '500']

    df['temp'] = None
    df['IS'] = None
    df['pH'] = None

    for i in temp_values:
        for index, row in df.iterrows():
            condition = row['Condition']
            if re.search(i, condition):
                df.loc[index, 'temp'] = i

    for i in IS_values:
        for index, row in df.iterrows():
            condition = row['Condition']
            if re.search(i, condition):
                df.loc[index, 'IS'] = int(i.strip("_"))

    for index, row in df.iterrows():
        condition = row['Condition']
        if re.search(r'^7_|_7_', condition):
            df.loc[index, 'pH'] = 7
        elif re.search(r'^8_|_8_', condition):
            df.loc[index, 'pH'] = 8
        elif re.search(r'^9_|_9_', condition):
            df.loc[index, 'pH'] = 9
        elif re.search(r'3_5', condition):
            df.loc[index, 'pH'] = 3.5
        elif re.search(r'4_5', condition):
            df.loc[index, 'pH'] = 4.5
        elif re.search(r'5_5', condition):
            df.loc[index, 'pH'] = 5.5

            
# Usage
# mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_number061123.xlsx", index_col=0)
# assign_conditions(mean_rmsf_nc_sasa_agg_total_sasa)

# %%
# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx")

# assign pH, temp, IS columns into the dataframe
assign_conditions(mean_rmsf_nc_sasa_agg_total_sasa)

# Save dataframe into an excel            
#mean_rmsf_nc_sasa_agg_total_sasa.to_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx")

# %% [markdown]
# ##### temperature

# %%
import pandas as pd

mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx",index_col=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(mean_rmsf_nc_sasa_agg_total_sasa, x="sum_aprsasa", y="ln(v)",hue = 'temp')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['sum_aprsasa'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')


# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(mean_rmsf_nc_sasa_agg_total_sasa, x="sum_aprsasa", y="ln(v)",hue = 'temp')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['sum_aprsasa'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')


# Show the plot
plt.show()

# %% [markdown]
# ##### pH

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx", index_col=0)


# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(data = mean_rmsf_nc_sasa_agg_total_sasa, x="sum_aprsasa", y="ln(v)",hue = 'pH',palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['sum_aprsasa'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')
# 13   0.171452  78.450867  0.981778      14   338    0  7.0
# 14   0.170038  76.655733  2.835914      15   338  100  9.0
# 15   0.128550  61.849600 -5.361700      16   277  150  3.5
# 16   0.179591  59.523867  9.878259      17   338  250  3.5
# 17   0.180716  76.815333  2.800305      18   338  500  9.0
# 18   0.182964  61.849600  9.593252      19   338  150  3.5
# 19   0.145754  81.310250 -3.675797      20   296  100  5.5
# 20   0.182638  83.169367  0.430820      21   338    0  4.5
# 21   0.180279  71.892150  7.094788      22   338  200  4.5
# 22   0.177834  76.800867  2.855701      23   338  400  9.0
# 23   0.177137  73.072700  6.852800      24   338  250  4.5
# 24   0.169808  76.500567  2.060694      25   338    0  9.0
# 25   0.142148  79.607500 -2.958218      26   296    0  5.5
# 26   0.177053  77.247800  2.053706      27   338  400  8.0
# 27   0.141569  80.332500 -3.699562      28   296  200  5.5
# 28   0.155223  78.629800 -2.806800      29   318  150  7.0
# 29   0.196368  77.966100  0.983300      30   338   50  7.0
# 30   0.172111  76.938400  2.827034      31   338  300  9.0
# 31   0.135151  77.345467 -4.823917      32   277  100  8.0
# 32   0.183606  77.850767  2.079565      33   338  300  8.0
# 33   0.163943  74.995800 -3.202900      34   318   50  4.5
# 34   0.178876  64.945700  9.317400      35   338   50  3.5
# 35   0.138893  80.357050 -4.092552      36   296  150  5.5
# 36   0.138708  79.713900 -3.605309      37   296   50  5.5
# 37   0.134526  77.927800 -4.860800      38   277  250  7.0
# 38   0.156921  59.523900  1.376900      39   318  250  3.5
# 39   0.141350  77.966067 -4.651002      40   296   50  7.0
# 40   0.131894  74.995800 -4.123900      41   296   50  4.5
# 41   0.183102  74.995800  4.900827      42   338   50  4.5
# 42   0.140163  78.629800 -5.324000      43   277  150  7.0
# 43   0.147359  59.523900 -3.813900      44   296  250  3.5
# 44   0.179242  73.955500  5.599474      45   338  100  4.5
# 45   0.143561  78.629833 -4.024684      46   296  150  7.0
# 46   0.177470  77.940967  2.182835      47   338  200  8.0
# 47   0.178461  73.311600  6.544445      48   338  150  4.5
# 48   0.130951  73.072700 -3.586700      49   277  250  4.5

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(data = mean_rmsf_nc_sasa_agg_total_sasa, x="sum_aprsasa", y="ln(v)",hue = 'IS',palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['sum_aprsasa'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

    

# Show the plot
plt.show()

# %% [markdown]
# Hmmm this plot does not have IS 150, 250, 50. Why?

# %% [markdown]
# #### A scatter plot of native contacts vs ln(v)

# %% [markdown]
# ##### Updated version

# %% [markdown]
# ##### temperature

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp061123.xlsx",index_col=0)

# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(mean_rmsf_nc_sasa_agg_total_sasa, x="Average native contact (last 50ns)", y="ln(v)",hue = 'temp',palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['Average native contact (last 50ns)'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

    
# Show the plot
plt.show()

# %% [markdown]
# ##### pH

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx",index_col=0)

# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(mean_rmsf_nc_sasa_agg_total_sasa, x="Average native contact (last 50ns)", y="ln(v)",hue = 'pH',palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['Average native contact (last 50ns)'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

    
# Show the plot
plt.show()

# %% [markdown]
# ##### IS

# %% [markdown]
# ###### update 19/11/23 - i was thinking maybe seaborn has a recent update so sns.scatterplot(data = mean_rmsf_nc_sasa_agg_total_sasa you have to use data =

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx",index_col=0)


# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(data =mean_rmsf_nc_sasa_agg_total_sasa, x="Average native contact (last 50ns)", y="ln(v)",hue = 'IS',palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['Average native contact (last 50ns)'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

    
# Show the plot
plt.show()

# %% [markdown]
# ##### Older version

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp311023.xlsx",index_col=0)

# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(mean_rmsf_nc_sasa_agg_total_sasa, x="Average native contact (last 50ns)", y="ln(v)",hue = 'temp')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['Average native contact (last 50ns)'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

    
# Show the plot
plt.show()

# %% [markdown]
# #### A scatter plot of the mean RMSF vs ln(v)

# %% [markdown]
# ##### temperature

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx",index_col=0)

# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(mean_rmsf_nc_sasa_agg_total_sasa, x="mean RMSF", y="ln(v)",hue = 'temp',palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['mean RMSF'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

    
# Show the plot
plt.show()

# %% [markdown]
# ##### pH

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx",index_col=0)

# Set the size of the plot
plt.figure(figsize=(6, 4))

sns.scatterplot(data = mean_rmsf_nc_sasa_agg_total_sasa, x="mean RMSF", y="ln(v)",hue = 'pH',palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['mean RMSF'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

    
# Show the plot
plt.show()

# %% [markdown]
# #### A scatter plot of non-polar SASA vs lnv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp061123.xlsx", index_col=0)

# Set the size of the plot
plt.figure(figsize=(6, 4))

# Specify a different color palette, e.g., "viridis"
sns.scatterplot(data=mean_rmsf_nc_sasa_agg_total_sasa, x="Non_polar SASA", y="ln(v)", hue='temp', palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['Non_polar SASA'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# ##### pH

# %% [markdown]
# ###### Updated 19/11/23

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx", index_col=0)

# Set the size of the plot
plt.figure(figsize=(6, 4))

# Specify a different color palette, e.g., "viridis"
sns.scatterplot(data=mean_rmsf_nc_sasa_agg_total_sasa, x="Non_polar SASA", y="ln(v)", hue='pH', palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['Non_polar SASA'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# ##### Older version

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp061123.xlsx", index_col=0)

# Set the size of the plot
plt.figure(figsize=(6, 4))

# Specify a different color palette, e.g., "viridis"
sns.scatterplot(data=mean_rmsf_nc_sasa_agg_total_sasa, x="Non_polar SASA", y="ln(v)", hue='pH', palette='coolwarm')

# Annotate each point with its label
for i, row in mean_rmsf_nc_sasa_agg_total_sasa.iterrows():
    plt.text(row['Non_polar SASA'], row['ln(v)'], row['Number'], fontsize=7, ha='left', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# #### A scatter plot of lnv vs Tm

# %% [markdown]
# ### Paper: A single molecular descriptor to predict solution behavior of therapeutic antibodies - Jonathan S. Kingsbury
#
# https://www.science.org/doi/full/10.1126/sciadv.abb0372

# %% [markdown]
# #### Spearman rank correlation

# %% [markdown]
# ##### sum_aprsasa vs ln(v) - updated 061123

# %%
import pandas as pd
from scipy.stats import spearmanr

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp061123.xlsx",index_col=0)

df = mean_rmsf_nc_sasa_agg_total_sasa

# Set column 'Number' as the index
df.set_index('Number', inplace=True)

# Calculate Spearman rank correlation
correlation, p_value = spearmanr(df['sum_aprsasa'], df['ln(v)'])


# # Display rank order output for the entire DataFrame
# rank_order_df = mean_rmsf_nc_sasa_agg_total_sasa.rank()
# display(rank_order_df)

# Display Spearman rank correlation
print(f"\nSpearman Rank Correlation: {correlation}")
print(f"P-value: {p_value}")
# Out:
# Spearman Rank Correlation: 0.6183673469387755
# P-value: 2.192730653769521e-06

# %%
rank_order_df = mean_rmsf_nc_sasa_agg_total_sasa.rank()
rank_order_df
# Out:
#         Condition  Non_polar SASA  Total SASA  \
# Number
# 1           16.00           11.00       11.00
# 2           39.00           30.00       29.00
# 3           18.00           38.00       38.00
# 4           20.00           42.00       42.00
# 5           32.00           18.00       18.00
# 6           46.00           40.00       40.00
# 7            9.00           27.00       27.00
# 8           17.00            7.00        7.00
# 9            5.00            8.00       10.00
# 10          22.00           28.00       28.00
# 11          11.00            4.00        4.00
# 12          35.00           13.00       12.00
# 13          43.00           29.00       30.00
# 14          37.00           44.00       44.00
# 15          45.00           43.00       43.00
# 16           3.00           10.00        8.00
# 17          21.00           41.00       41.00
# 18          49.00           46.00       46.00
# 19          19.00           33.00       33.00
# 20          29.00           15.00       13.00
# 21          23.00           37.00       37.00
# 22          26.00           48.00       47.00
# 23          48.00           35.00       35.00
# 24          15.00            3.00        3.00
# 25          44.00           31.00       31.00
# 26          28.00            6.00        6.00
# 27          42.00           25.00       25.00
# 28          31.00            9.00        9.00
# 29           8.00           21.00       23.00
# 30          13.00           47.00       48.00
# 31          47.00           32.00       32.00
# 32          38.00           12.00       14.00
# 33          41.00           39.00       39.00
# 34          12.00            2.00        2.00
# 35          14.00           23.00       24.00
# 36          30.00           16.00       17.00
# 37          33.00           22.00       19.00
# 38           2.00           17.00       16.00
# 39          10.00           24.00       22.00
# 40          36.00           20.00       21.00
# 41           7.00            1.00        1.00
# 42          27.00           45.00       45.00
# 43           1.00           19.00       20.00
# 44           6.00           14.00       15.00
# 45          24.00           36.00       34.00
# 46          34.00           34.00       36.00
# 47          40.00           26.00       26.00
# 48          25.00           49.00       49.00
# 49           4.00            5.00        5.00
#
#         Average native contact (last 50ns)  r_31-36  r_47-51  r_114-118  \
# Number
# 1                                    37.00    10.00     9.00      23.00
# 2                                    14.00    28.00    42.00      30.00
# 3                                    16.00    22.00    34.00      47.00
# 4                                     3.00    45.00    43.00      39.00
# 5                                    38.00     9.00    11.00      10.00
# 6                                    17.00    44.00    37.00      22.00
# 7                                    28.00    29.00    36.00      26.00
# 8                                    39.00    11.00    22.00      12.00
# 9                                    30.00     4.00    10.00      14.00
# 10                                   27.00    27.00    24.00      35.00
# 11                                   46.00     6.00     4.00       4.00
# 12                                   41.00    24.00    28.00       5.00
# 13                                   12.00    41.00    38.00      38.00
# 14                                   24.00    46.00    45.00      42.00
# 15                                   23.00    35.00    47.00      44.00
# 16                                   43.00     3.00    17.00      13.00
# 17                                   13.00    33.00    40.00      27.00
# 18                                    8.00    48.00    41.00      43.00
# 19                                    6.00    14.00    12.00      21.00
# 20                                   36.00    17.00     7.00      28.00
# 21                                    2.00    34.00    29.00      18.00
# 22                                   11.00    42.00    39.00      48.00
# 23                                   18.00    23.00    27.00      40.00
# 24                                   45.00     8.00     3.00       2.00
# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp061123.xlsx",index_col=0)

df = mean_rmsf_nc_sasa_agg_total_sasa

# Set column 'Number' as the index
df.set_index('Number', inplace=True)


# Calculate Spearman rank correlation
result = pg.pairwise_corr(df, method='spearman')

# Save the result to an excel file
#result.to_excel("SpearmanRankCorrelationAllVariables011123.xlsx")

# %% [markdown]
# ###### pandas

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp311023.xlsx",index_col=0)

df = mean_rmsf_nc_sasa_agg_total_sasa

# Set column 'Number' as the index
df.set_index('Number', inplace=True)

df = df.drop(['Condition'],axis = 1)

# To find the correlation among
# the columns using pearson method
df_correlation = df.corr(method ='spearman')


# plot a heatmap
sns.heatmap(df_correlation, annot=True, annot_kws={"fontsize":5}, fmt=".2f",linewidth=.5,vmin = -1,vmax = 1)
# Out:
# <Axes: >

# %% [markdown]
# ##### update 15/11/23 include HBonds

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa_hbond = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx",index_col=0)

df = mean_rmsf_nc_sasa_agg_total_sasa_hbond

# Set column 'Number' as the index
df.set_index('Number', inplace=True)

# if the column has a condition, delete it
try:
    df = df.drop(['Condition'],axis = 1)
    
except Exception:
    pass

# To find the correlation among
# the columns using pearson method
df_correlation = df.corr(method ='spearman')


# plot a heatmap
sns.heatmap(df_correlation, annot=True, annot_kws={"fontsize":5}, fmt=".2f",linewidth=.5,vmin = -1,vmax = 1)
# Out:
# <Axes: >

# %%
mean_rmsf_nc_sasa_agg_total_sasa_hbond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 3_5_277_0 to 277_4_5_250M
# Data columns (total 19 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Number of hydrogen bonds in the last 50ns  49 non-null     float64
#  1   Non_polar SASA                             49 non-null     float64
#  2   Total SASA                                 49 non-null     float64
#  3   Average native contact (last 50ns)         49 non-null     float64
#  4   r_31-36                                    49 non-null     float64
#  5   r_47-51                                    49 non-null     float64
#  6   r_114-118                                  49 non-null     float64
#  7   r_129-139                                  49 non-null     float64
#  8   r_261-265                                  49 non-null     float64
#  9   r_325-329                                  49 non-null     float64
#  10  r_387-402                                  49 non-null     float64
#  11  sum_aprsasa                                49 non-null     float64
#  12  mean RMSF                                  49 non-null     float64
#  13  Tm                                         49 non-null     float64
#  14  ln(v)                                      49 non-null     float64
#  15  Number                                     49 non-null     int64
#  16  temp                                       49 non-null     int64
#  17  IS                                         49 non-null     int64
#  18  pH                                         49 non-null     float64
# dtypes: float64(16), int64(3)
# memory usage: 7.7+ KB

# %% [markdown]
# #### Pearson test

# %% [markdown]
# ##### Try pearson test

# %%
import pandas as pd
import pingouin as pg

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_tem
# 20      81.310250 -3.675797   296  100  5.5
# 21      83.169367  0.430820   338   _0  4.5
# 22      71.892150  7.094788   338  200  4.5
# 23      76.800867  2.855701   338  400  9.0
# 24      73.072700  6.852800   338  250  4.5
# 25      76.500567  2.060694   338   _0  9.0
# 26      79.607500 -2.958218   296   _0  5.5
# 27      77.247800  2.053706   338  400  8.0
# 28      80.332500 -3.699562   296  200  5.5
# 29      78.629800 -2.806800   318  150  7.0
# 30      77.966100  0.983300   338   50  7.0
# 31      76.938400  2.827034   338  300  9.0
# 32      77.345467 -4.823917   277  100  8.0
# 33      77.850767  2.079565   338  300  8.0
# 34      74.995800 -3.202900   318   50  5.5
# 35      64.945700  9.317400   338   50  5.5
# 36      80.357050 -4.092552   296  150  5.5
# 37      79.713900 -3.605309   296   50  5.5
# 38      77.927800 -4.860800   277  250  7.0
# 39      59.523900  1.376900   318  250  3.5
# 40      77.966067 -4.651002   296   50  7.0
# 41      74.995800 -4.123900   296   50  5.5
# 42      74.995800  4.900827   338   50  4.5
# 43      78.629800 -5.324000   277  150  7.0
# 44      59.523900 -3.813900   296  250  3.5
# 45      73.955500  5.599474   338  100  4.5
# 46      78.629833 -4.024684   296  150  7.0
# 47      77.940967  2.182835   338  200  8.0
# 48      73.311600  6.544445   338  150  4.5
# 49      73.072700 -3.586700   277  250  4.5

# %%
import pandas as pd
import pingouin as pg

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp311023.xlsx",index_col=0)

df = mean_rmsf_nc_sasa_agg_total_sasa

# Set column 'Number' as the index
df.set_index('Number', inplace=True)

df = df.drop(['Condition'],axis = 1)


# Calculate Spearman rank correlation
pearson = df.rcorr(method='pearson')

# Save the result to an excel file
#pearson.to_csv("PearsonMatrixAllVariables011123.csv")

# %%
pearson
# Out:
#                                    Non_polar SASA Total SASA  \
# Non_polar SASA                                  -        ***
# Total SASA                                  0.908          -
# Average native contact (last 50ns)         -0.438      -0.76
# r_31-36                                       0.8      0.748
# r_47-51                                     0.815      0.764
# r_114-118                                   0.824      0.744
# r_129-139                                   0.864      0.757
# r_261-265                                   0.746      0.695
# r_325-329                                   0.746      0.657
# r_387-402                                    0.88      0.731
# sum_aprsasa                                 0.974      0.863
# mean RMSF                                    0.69      0.514
# Tm                                         -0.037     -0.007
# ln(v)                                       0.622      0.453
# temp                                        0.662      0.471
# IS                                          0.118      0.092
# pH                                          0.428       0.28
#
#                                    Average native contact (last 50ns) r_31-36  \
# Non_polar SASA                                                     **     ***
# Total SASA                                                        ***     ***
# Average native contact (last 50ns)                                  -      **
# r_31-36                                                        -0.371       -
# r_47-51                                                        -0.432   0.847
# r_114-118                                                      -0.363   0.544
# r_129-139                                                      -0.351   0.604
# r_261-265                                                      -0.358   0.633
# r_325-329                                                      -0.261   0.644
# r_387-402                                                      -0.238   0.648
# sum_aprsasa                                                    -0.385   0.818
# mean RMSF                                                       0.008   0.643
# Tm                                                             -0.053   0.095
# ln(v)                                                           0.004   0.552
# temp                                                            0.042   0.638
# IS                                                              0.001    0.26
# pH                                                              0.078   0.484
#
#                                    r_47-51 r_114-118 r_129-139 r_261-265  \
# Non_polar SASA                         ***       ***       ***       ***
# Total SASA                             ***       ***       ***       ***
# Average native contact (last 50ns)      **         *         *         *
# r_31-36                                ***       ***       ***       ***
# r_47-51                                  -       ***       ***       ***
# r_114-118                            0.586         -       ***       ***
# r_129-139                            0.579     0.833         -       ***
# r_261-265                            0.754     0.496     0.505         -
# r_325-329                            0.675     0.513     0.603     0.648
# r_387-402                            0.636     0.796     0.846     0.503
# sum_aprsasa                          0.828     0.842     0.889     0.719
# mean RMSF                            0.568     0.467     0.511     0.547
# Tm                                   0.032    -0.041    -0.121    -0.009
# ln(v)                                0.502     0.422     0.542     0.465
# temp                                 0.575     0.399       0.5     0.588
# IS                                   0.195     0.006     0.047     0.141
# pH                                   0.426     0.242     0.283     0.335
#
#                                    r_325-329 r_387-402 sum_aprsasa mean RMSF  \
# Non_polar SASA                           ***       ***         ***       ***
# Total SASA                               ***       ***         ***       ***
# Average native contact (last 50ns)                              **
# r_31-36                                  ***       ***         ***       ***
# r_47-51                                  ***       ***         ***       ***
# r_114-118                                ***       ***         ***       ***
# r_129-139                                ***       ***         ***       ***
# r_261-265                                ***       ***         ***       ***
# r_325-329                                  -       ***         ***       ***
# r_387-402                               0.67         -         ***       ***
# sum_aprsasa                            0.784      0.92           -       ***
# mean RMSF                               0.54     0.612       0.662         -
# Tm                                      0.12    -0.019      -0.006    -0.126
# ln(v)                                  0.464     0.569       0.609     0.836
# temp                                   0.506     0.582       0.642      0.95
# IS                                     0.063    -0.038       0.089     0.221
# pH                                     0.311     0.382       0.417     0.654
#
#                                         Tm  ln(v)   temp     IS   pH
# Non_polar SASA                                ***    ***          **
# Total SASA                                     **    ***
# Average native contact (last 50ns)
# r_31-36                                       ***    ***         ***
# r_47-51                                       ***    ***          **
# r_114-118                                      **     **
# r_129-139                                     ***    ***           *
# r_261-265                                     ***    ***           *
# r_325-329                                     ***    ***           *
# r_387-402                                     ***    ***          **
# sum_aprsasa                                   ***    ***          **
# mean RMSF                                     ***    ***         ***
# Tm                                       -     **
# ln(v)                               -0.436      -    ***         ***
# temp                                -0.085  0.843      -         ***
# IS                                  -0.066  0.147  0.179      -
# pH                                  -0.118   0.62  0.642  0.127    -

# %% [markdown]
# ##### Pandas corr() function

# %% [markdown]
# ##### Updated updated version 19/11/23

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp_hbond151123.xlsx",index_col=0)

df = mean_rmsf_nc_sasa_agg_total_sasa

# Set column 'Number' as the index
df.set_index('Number', inplace=True)

df = df.drop(['Condition'],axis = 1)

# To find the correlation among
# the columns using pearson method
df_correlation = df.corr(method ='pearson')

# save the pearson correlation to an excel
#df_correlation.to_excel("PearsonCorrelationMatrixPandas011123.xlsx")


# plot a heatmap
sns.heatmap(df_correlation, annot=True, annot_kws={"fontsize":5}, fmt=".2f",linewidth=.5, vmin = -1, vmax = 1)
# Out:
# <Axes: >

# %% [markdown]
# ##### Updated version

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp061123.xlsx",index_col=0)

df = mean_rmsf_nc_sasa_agg_total_sasa

# Set column 'Number' as the index
df.set_index('Number', inplace=True)

df = df.drop(['Condition'],axis = 1)

# To find the correlation among
# the columns using pearson method
df_correlation = df.corr(method ='pearson')

# save the pearson correlation to an excel
#df_correlation.to_excel("PearsonCorrelationMatrixPandas011123.xlsx")


# plot a heatmap
sns.heatmap(df_correlation, annot=True, annot_kws={"fontsize":5}, fmt=".2f",linewidth=.5, vmin = -1, vmax = 1)
# Out:
# <Axes: >

# %% [markdown]
# ##### older version

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# read dataframe
mean_rmsf_nc_sasa_agg_total_sasa = pd.read_excel("mean_rmsf_nc_sasa_agg_total_sasa_temp311023.xlsx",index_col=0)

df = mean_rmsf_nc_sasa_agg_total_sasa

# Set column 'Number' as the index
df.set_index('Number', inplace=True)

df = df.drop(['Condition'],axis = 1)

# To find the correlation among
# the columns using pearson method
df_correlation = df.corr(method ='pearson')

# save the pearson correlation to an excel
#df_correlation.to_excel("PearsonCorrelationMatrixPandas011123.xlsx")


# plot a heatmap
sns.heatmap(df_correlation, annot=True, annot_kws={"fontsize":5}, fmt=".2f",linewidth=.5, vmin = -1, vmax = 1)
# Out:
# <Axes: >

# %%
df_correlation
# Out:
#                                     Non_polar SASA  Total SASA  \
# Non_polar SASA                            1.000000    0.907948
# Total SASA                                0.907948    1.000000
# Average native contact (last 50ns)       -0.438160   -0.759793
# r_31-36                                   0.800258    0.747617
# r_47-51                                   0.814541    0.763851
# r_114-118                                 0.824265    0.743911
# r_129-139                                 0.863555    0.756676
# r_261-265                                 0.746217    0.695162
# r_325-329                                 0.746464    0.656762
# r_387-402                                 0.879519    0.731386
# sum_aprsasa                               0.974006    0.863313
# mean RMSF                                 0.690069    0.514039
# Tm                                       -0.036795   -0.007323
# ln(v)                                     0.622028    0.453103
# temp                                      0.661968    0.471494
# IS                                        0.118160    0.092016
# pH                                        0.427731    0.279511
#
#                                     Average native contact (last 50ns)  \
# Non_polar SASA                                               -0.438160
# Total SASA                                                   -0.759793
# Average native contact (last 50ns)                            1.000000
# r_31-36                                                      -0.371163
# r_47-51                                                      -0.432095
# r_114-118                                                    -0.363086
# r_129-139                                                    -0.350659
# r_261-265                                                    -0.357573
# r_325-329                                                    -0.260635
# r_387-402                                                    -0.237737
# sum_aprsasa                                                  -0.384751
# mean RMSF                                                     0.007856
# Tm                                                           -0.053302
# ln(v)                                                         0.004051
# temp                                                          0.042069
# IS                                                            0.000919
# pH                                                            0.077951
#
#                                      r_31-36   r_47-51  r_114-118  r_129-139  \
# Non_polar SASA                      0.800258  0.814541   0.824265   0.863555
# Total SASA                          0.747617  0.763851   0.743911   0.756676
# Average native contact (last 50ns) -0.371163 -0.432095  -0.363086  -0.350659
# r_31-36                             1.000000  0.846537   0.544229   0.603911
# r_47-51                             0.846537  1.000000   0.585527   0.578789
# r_114-118                           0.544229  0.585527   1.000000   0.833036
# r_129-139                           0.603911  0.578789   0.833036   1.000000
# r_261-265                           0.632661  0.754315   0.495594   0.505008
# r_325-329                           0.644192  0.675374   0.512709   0.603252
# r_387-402                           0.647781  0.636320   0.796057   0.846455
# sum_aprsasa                         0.818157  0.828312   0.841995   0.889178
